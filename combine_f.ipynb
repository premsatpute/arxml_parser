# %%
import xml.etree.ElementTree as ET
import re
import os
import json
from collections import defaultdict
import pandas as pd
from difflib import get_close_matches

# %%
# PDU Metadata Extractor with Signal Breakdown

import xml.etree.ElementTree as ET
import json
import os
from collections import defaultdict

NS = {'autosar': 'http://autosar.org/schema/r4.0'}

SERVICE_FILE = "Service_Instance_A14_Ver_3.2 1.arxml"
RBS_FILE = "RBS_A14_Ver_3.2 3.arxml"
OUTPUT_JSON = "pdu_signal_metadata.json"
DEBUG_LOG = "debug_log.txt"

def log_debug(msg):
    with open(DEBUG_LOG, 'a') as f:
        f.write(msg + "\n")

def normalize_name(name):
    return name.replace("SomeIp", "").replace("_SI", "").replace("_", "").lower()

# %%
def parse_service_interfaces(service_path):
    service_map = {}
    tree = ET.parse(service_path)
    root = tree.getroot()
    for si in root.findall('.//autosar:SOMEIP-SERVICE-INTERFACE-DEPLOYMENT', NS):
        si_name = si.find('autosar:SHORT-NAME', NS).text
        sid = si.find('.//autosar:SERVICE-INTERFACE-ID', NS)

        # Use EVENT-DEPLOYMENTS instead of SOMEIP-EVENT to fetch EVENT-IDs correctly
        event_deployments = si.findall('.//autosar:EVENT-DEPLOYMENTS/autosar:SOMEIP-EVENT-DEPLOYMENT', NS)
        event_ids = []
        for ev in event_deployments:
            eid = ev.find('autosar:EVENT-ID', NS)
            if eid is not None:
                event_ids.append(eid.text)

        key = normalize_name(si_name)
        service_map[key] = {
            'service_interface': si_name,
            'service_id': sid.text if sid is not None else '',
            'event_ids': ','.join(event_ids)
        }
    return service_map

# %%
service_data = parse_service_interfaces(SERVICE_FILE)

# %%
service_data
# Out:
# {'bms1fd20': {'service_interface': 'SomeIpBMS1_FD_20_SI',
#   'service_id': '518',
#   'event_ids': '32775'},
#  'bms2fd100': {'service_interface': 'SomeIpBMS2_FD_100_SI',
#   'service_id': '781',
#   'event_ids': '32775'},
#  'bms3fd100': {'service_interface': 'SomeIpBMS3_FD_100_SI',
#   'service_id': '915',
#   'event_ids': '32775'},
#  'bmscannm': {'service_interface': 'SomeIpBMS_CANNM_SI',
#   'service_id': '916',
#   'event_ids': '32775'},
#  'ccm11200': {'service_interface': 'SomeIpCCM11_200_SI',
#   'service_id': '1250',
#   'event_ids': '32771'},
#  'ccm1200': {'service_interface': 'SomeIpCCM1_200_SI',
#   'service_id': '768',
#   'event_ids': '32771'},
#  'ccm2200': {'service_interface': 'SomeIpCCM2_200_SI',
#   'service_id': '770',
#   'event_ids': '32771'},
#  'ccm3200': {'service_interface': 'SomeIpCCM3_200_SI',
#   'service_id': '771',
#   'event_ids': '32771'},
#  'ccm4200': {'service_interface': 'SomeIpCCM4_200_SI',
#   'service_id': '772',
#   'event_ids': '32771'},
#  'ccm5test200': {'service_interface': 'SomeIpCCM5_TEST_200_SI',
#   'service_id': '774',
#   'event_ids': '32771'},
#  'ccm6test200': {'service_interface': 'SomeIpCCM6_TEST_200_SI',
#   'service_id': '775',
#   'event_ids': '32771'},
#  'ccm7test200': {'service_interface': 'SomeIpCCM7_TEST_200_SI',
#   'service_id': '777',
#   'event_ids': '32771'},
#  'ccm8200': {'service_interface': 'SomeIpCCM8_200_SI',
#   'service_id': '1172',
#   'event_ids': '32771'},
#  'ccm9200': {'service_interface': 'SomeIpCCM9_200_SI',
#   'service_id': '1173',
#   'event_ids': '32771'},
#  'ccmcannm': {'service_interface': 'SomeIpCCM_CANNM_SI',
#   'service_id': '926',
#   'event_ids': '32771'},
#  'eps1fd10': {'service_interface': 'SomeIpEPS1_FD_10_SI',
#   'service_id': '314',
#   'event_ids': '32769'},
#  'escl1fd100': {'service_interface': 'SomeIpESCL1_FD_100_SI',
#   'service_id': '974',
#   'event_ids': '32769'},
#  'escl2sp': {'service_interface': 'SomeIpESCL2_SP_SI_SI',
#   'service_id': '162',
#   'event_ids': '32769'},
#  'frontzone1sp': {'service_interface': 'SomeIpFRONTZONE1_SP_SI',
#   'service_id': '163',
#   'event_ids': '32770'},
#  'frontzone3mcmsp': {'service_interface': 'SomeIpFRONTZONE3_MCM_SP_SI',
#   'service_id': '168',
#   'event_ids': '32770'},
#  'frontzone4mcmsp': {'service_interface': 'SomeIpFRONTZONE4_MCM_SP_SI',
#   'service_id': '169',
#   'event_ids': '32770'},
#  'frontzone5vcusp': {'service_interface': 'SomeIpFRONTZONE5_VCU_SP_SI',
#   'service_id': '170',
#   'event_ids': '32770'},
#  'frontzone6vcusp': {'service_interface': 'SomeIpFRONTZONE6_VCU_SP_SI',
#   'service_id': '171',
#   'event_ids': '32770'},
#  'frontzone7bmssp': {'service_interface': 'SomeIpFRONTZONE7_BMS_SP_SI',
#   'service_id': '172',
#   'event_ids': '32770'},
#  'frontzone8mcusp': {'service_interface': 'SomeIpFRONTZONE8_MCU_SP_SI',
#   'service_id': '173',
#   'event_ids': '32770'},
#  'frontzone9sp': {'service_interface': 'SomeIpFRONTZONE9_SP_SI',
#   'service_id': '174',
#   'event_ids': '32770'},
#  'frontzonecannm': {'service_interface': 'SomeIpFRONT_ZONE_CANNM_SI',
#   'service_id': '910',
#   'event_ids': '32770'},
#  'frzone10sp': {'service_interface': 'SomeIpFR_ZONE10_SP_SI',
#   'service_id': '1435',
#   'event_ids': '32770'},
#  'frzone11sp': {'service_interface': 'SomeIpFR_ZONE11_SP_SI',
#   'service_id': '1436',
#   'event_ids': '32770'},
#  'frzone12sp': {'service_interface': 'SomeIpFR_ZONE12_SP_SI',
#   'service_id': '139',
#   'event_ids': '32770'},
#  'frzone13sp': {'service_interface': 'SomeIpFR_ZONE13_SP_SI',
#   'service_id': '179',
#   'event_ids': '32770'},
#  'frzone15sp': {'service_interface': 'SomeIpFR_ZONE15_SP_SI',
#   'service_id': '180',
#   'event_ids': '32770'},
#  'frzone17100': {'service_interface': 'SomeIpFR_ZONE17_100_SI',
#   'service_id': '889',
#   'event_ids': '32770'},
#  'frzone110': {'service_interface': 'SomeIpFR_ZONE1_10_SI',
#   'service_id': '317',
#   'event_ids': '32770'},
#  'frzone2100': {'service_interface': 'SomeIpFR_ZONE2_100_SI',
#   'service_id': '793',
#   'event_ids': '32770'},
#  'frzone3100': {'service_interface': 'SomeIpFR_ZONE3_100_SI',
#   'service_id': '794',
#   'event_ids': '32770'},
#  'frzone6100': {'service_interface': 'SomeIpFR_ZONE6_100_SI',
#   'service_id': '1096',
#   'event_ids': '32770'},
#  'hpcad1050': {'service_interface': 'SomeIpHPCAd_10_50_SI',
#   'service_id': '693',
#   'event_ids': '32769'},
#  'hpcad1150': {'service_interface': 'SomeIpHPCAd_11_50_SI',
#   'service_id': '694',
#   'event_ids': '32769'},
#  'hpcad1250': {'service_interface': 'SomeIpHPCAd_12_50_SI',
#   'service_id': '695',
#   'event_ids': '32769'},
#  'hpcad1350': {'service_interface': 'SomeIpHPCAd_13_50_SI',
#   'service_id': '696',
#   'event_ids': '32769'},
#  'hpcad1450': {'service_interface': 'SomeIpHPCAd_14_50_SI',
#   'service_id': '698',
#   'event_ids': '32769'},
#  'hpcad1550': {'service_interface': 'SomeIpHPCAd_15_50_SI',
#   'service_id': '699',
#   'event_ids': '32769'},
#  'hpcad1650': {'service_interface': 'SomeIpHPCAd_16_50_SI',
#   'service_id': '700',
#   'event_ids': '32769'},
#  'hpcad110': {'service_interface': 'SomeIpHPCAd_1_10_SI',
#   'service_id': '318',
#   'event_ids': '32769'},
#  'hpcad250': {'service_interface': 'SomeIpHPCAd_2_50_SI',
#   'service_id': '687',
#   'event_ids': '32769'},
#  'hpcad350': {'service_interface': 'SomeIpHPCAd_3_50_SI',
#   'service_id': '689',
#   'event_ids': '32769'},
#  'hpcad410': {'service_interface': 'SomeIpHPCAd_4_10_SI',
#   'service_id': '319',
#   'event_ids': '32769'},
#  'hpcad750': {'service_interface': 'SomeIpHPCAd_7_50_SI',
#   'service_id': '690',
#   'event_ids': '32769'},
#  'hpcad850': {'service_interface': 'SomeIpHPCAd_8_50_SI',
#   'service_id': '691',
#   'event_ids': '32769'},
#  'hpcad950': {'service_interface': 'SomeIpHPCAd_9_50_SI',
#   'service_id': '692',
#   'event_ids': '32769'},
#  'hpcap110': {'service_interface': 'SomeIpHPCAp_1_10_SI',
#   'service_id': '367',
#   'event_ids': '32769'},
#  'hpcap2100': {'service_interface': 'SomeIpHPCAp_2_100_SI',
#   'service_id': '935',
#   'event_ids': '32769'},
#  'hpcap3200': {'service_interface': 'SomeIpHPCAp_3_200_SI',
#   'service_id': '1175',
#   'event_ids': '32769'},
#  'hpcc10100': {'service_interface': 'SomeIpHPCC_10_100_SI',
#   'service_id': '1147',
#   'event_ids': '32776'},
#  'hud1200': {'service_interface': 'SomeIpHUD1_200_SI',
#   'service_id': '1171',
#   'event_ids': '32771'},
#  'icc250': {'service_interface': 'SomeIpICC2_50_SI',
#   'service_id': '767',
#   'event_ids': '32771'},
#  'icccannm': {'service_interface': 'SomeIpICC_CANNM_SI',
#   'service_id': '909',
#   'event_ids': '32771'},
#  'ieb1fd10': {'service_interface': 'SomeIpIEB1_FD_10_SI',
#   'service_id': '315',
#   'event_ids': '32769'},
#  'ieb2fd100': {'service_interface': 'SomeIpIEB2_FD_100_SI',
#   'service_id': '796',
#   'event_ids': '32769'},
#  'mcu11fd100': {'service_interface': 'SomeIpMCU11_FD_100_SI',
#   'service_id': '890',
#   'event_ids': '32775'},
#  'mcu12fd10': {'service_interface': 'SomeIpMCU12_FD_10_SI',
#   'service_id': '303',
#   'event_ids': '32775'},
#  'midzone1100': {'service_interface': 'SomeIpMID_ZONE1_100_SI',
#   'service_id': '795',
#   'event_ids': '32770'},
#  'midzone210': {'service_interface': 'SomeIpMID_ZONE2_10_SI',
#   'service_id': '371',
#   'event_ids': '32770'},
#  'ocdc1fd100': {'service_interface': 'SomeIpOCDC1_FD_100_SI',
#   'service_id': '898',
#   'event_ids': '32775'},
#  'ocdc2fd10': {'service_interface': 'SomeIpOCDC2_FD_10_SI',
#   'service_id': '373',
#   'event_ids': '32775'},
#  'sbw1fd10': {'service_interface': 'SomeIpSBW1_FD_10_SI',
#   'service_id': '592',
#   'event_ids': '32769'},
#  'srs1fd10': {'service_interface': 'SomeIpSRS1_FD_10_SI',
#   'service_id': '316',
#   'event_ids': '32769'},
#  'srsdiagres': {'service_interface': 'SomeIpSRS_DIAG_RES_SI',
#   'service_id': '1848',
#   'event_ids': '32769'},
#  'vcu11fd10': {'service_interface': 'SomeIpVCU11_FD_10_SI',
#   'service_id': '366',
#   'event_ids': '32769'},
#  'vcu12fd100': {'service_interface': 'SomeIpVCU12_FD_100_SI',
#   'service_id': '1009',
#   'event_ids': '32769'},
#  'vcu1fd20': {'service_interface': 'SomeIpVCU1_FD_20_SI',
#   'service_id': '519',
#   'event_ids': '32769'},
#  'vcu2fd100': {'service_interface': 'SomeIpVCU2_FD_100_SI',
#   'service_id': '782',
#   'event_ids': '32769'},
#  'vcu3fd100': {'service_interface': 'SomeIpVCU3_FD_100_SI',
#   'service_id': '850',
#   'event_ids': '32769'},
#  'vcu4fd1500': {'service_interface': 'SomeIpVCU4_FD_1500_SI',
#   'service_id': '1008',
#   'event_ids': '32769'},
#  'vcucannm': {'service_interface': 'SomeIpVCU_CANNM_SI',
#   'service_id': '911',
#   'event_ids': '32769'},
#  'wlc12000': {'service_interface': 'SomeIpWLC1_2000_SI',
#   'service_id': '1684',
#   'event_ids': '32770'},
#  'wlc22000': {'service_interface': 'SomeIpWLC2_2000_SI',
#   'service_id': '1685',
#   'event_ids': '32770'}}

# %%
def infer_cycle_time_from_name(pdu_name):
    match = re.search(r'_([0-9]{2,4})$', pdu_name)
    if match:
        return str(float(match.group(1)) / 1000)
    return "0.0"
def parse_rbs_pdus(rbs_path):
    tree = ET.parse(rbs_path)
    root = tree.getroot()
    pdu_map = {}

    # Create a lookup for signal lengths
    signal_length_map = {}
    for signal in root.findall('.//autosar:I-SIGNAL', NS):
        signal_name = signal.find('autosar:SHORT-NAME', NS).text
        length_elem = signal.find('autosar:LENGTH', NS)
        signal_length = length_elem.text if length_elem is not None else '0'
        signal_length_map[signal_name] = signal_length

    for pdu in root.findall('.//autosar:I-SIGNAL-I-PDU', NS):
        pdu_name_elem = pdu.find('autosar:SHORT-NAME', NS)
        pdu_name = pdu_name_elem.text if pdu_name_elem is not None else 'Unnamed_PDU'

        length_elem = pdu.find('autosar:LENGTH', NS)
        length = length_elem.text if length_elem is not None else '0'

        timing = pdu.find('.//autosar:CYCLIC-TIMING', NS)
        cycle_time = infer_cycle_time_from_name(pdu_name)
        
        signals = {}
        signal_mappings = pdu.findall('.//autosar:I-SIGNAL-TO-PDU-MAPPINGS/autosar:I-SIGNAL-TO-I-PDU-MAPPING', NS)
        signal_count = 0

        for mapping in signal_mappings:
            sig_ref = mapping.find('autosar:I-SIGNAL-REF', NS)
            if sig_ref is not None:
                sig_name = sig_ref.text.split('/')[-1]
                start_pos = mapping.find('autosar:START-POSITION', NS)
                byte_order = mapping.find('autosar:PACKING-BYTE-ORDER', NS)
                # Fetch signal length from the signal_length_map
                signal_len = signal_length_map.get(sig_name, '0')
                signals[sig_name] = {
                    f"{sig_name}_value": 0,
                    f"{sig_name}_Byte_order": byte_order.text if byte_order is not None else 'Unknown',
                    f"{sig_name}_start_bit": int(start_pos.text) if start_pos is not None else -1,
                    f"{sig_name}_len": signal_len
                }
                signal_count += 1

        pdu_map[pdu_name] = {
            'length': length,
            'cycle_time': cycle_time,
            'signals': signals,
            'total_signals': signal_count
        }
    return pdu_map

# %%
pdu_data = parse_rbs_pdus(RBS_FILE)

# %%
pdu_data
# Out:
# {'BMS1_FD_20': {'length': '64',
#   'cycle_time': '0.02',
#   'signals': {'BMS_BATTERY_BUS_VOLTAGE': {'BMS_BATTERY_BUS_VOLTAGE_value': 0,
#     'BMS_BATTERY_BUS_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_BUS_VOLTAGE_start_bit': 0,
#     'BMS_BATTERY_BUS_VOLTAGE_len': '13'},
#    'BMS_DISCONNECT_BY_BMS': {'BMS_DISCONNECT_BY_BMS_value': 0,
#     'BMS_DISCONNECT_BY_BMS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_DISCONNECT_BY_BMS_start_bit': 13,
#     'BMS_DISCONNECT_BY_BMS_len': '1'},
#    'BMS_BATTERY_PACK_CURRENT': {'BMS_BATTERY_PACK_CURRENT_value': 0,
#     'BMS_BATTERY_PACK_CURRENT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_PACK_CURRENT_start_bit': 16,
#     'BMS_BATTERY_PACK_CURRENT_len': '14'},
#    'BMS_FC_NEGATIVE_CONTACTOR_STATE': {'BMS_FC_NEGATIVE_CONTACTOR_STATE_value': 0,
#     'BMS_FC_NEGATIVE_CONTACTOR_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_FC_NEGATIVE_CONTACTOR_STATE_start_bit': 32,
#     'BMS_FC_NEGATIVE_CONTACTOR_STATE_len': '3'},
#    'BMS_NEGATIVE_CONTACTOR_STATE': {'BMS_NEGATIVE_CONTACTOR_STATE_value': 0,
#     'BMS_NEGATIVE_CONTACTOR_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_NEGATIVE_CONTACTOR_STATE_start_bit': 35,
#     'BMS_NEGATIVE_CONTACTOR_STATE_len': '3'},
#    'BMS_MODULE_ACTIVE_DISCHARGE': {'BMS_MODULE_ACTIVE_DISCHARGE_value': 0,
#     'BMS_MODULE_ACTIVE_DISCHARGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_MODULE_ACTIVE_DISCHARGE_start_bit': 38,
#     'BMS_MODULE_ACTIVE_DISCHARGE_len': '2'},
#    'BMS_OPERATION_MODE': {'BMS_OPERATION_MODE_value': 0,
#     'BMS_OPERATION_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_OPERATION_MODE_start_bit': 40,
#     'BMS_OPERATION_MODE_len': '5'},
#    'BATTERY_CONNECTION_STATUS': {'BATTERY_CONNECTION_STATUS_value': 0,
#     'BATTERY_CONNECTION_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BATTERY_CONNECTION_STATUS_start_bit': 45,
#     'BATTERY_CONNECTION_STATUS_len': '3'},
#    'BMS_BCONTACTOR_OFF_REQ': {'BMS_BCONTACTOR_OFF_REQ_value': 0,
#     'BMS_BCONTACTOR_OFF_REQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BCONTACTOR_OFF_REQ_start_bit': 54,
#     'BMS_BCONTACTOR_OFF_REQ_len': '1'},
#    'BATT_COOLING_PRIORITY_BIT': {'BATT_COOLING_PRIORITY_BIT_value': 0,
#     'BATT_COOLING_PRIORITY_BIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BATT_COOLING_PRIORITY_BIT_start_bit': 62,
#     'BATT_COOLING_PRIORITY_BIT_len': '2'},
#    'BMS_HIGH_VOLTAGE_1': {'BMS_HIGH_VOLTAGE_1_value': 0,
#     'BMS_HIGH_VOLTAGE_1_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_VOLTAGE_1_start_bit': 64,
#     'BMS_HIGH_VOLTAGE_1_len': '13'},
#    'BMS_ERROR_STATUS': {'BMS_ERROR_STATUS_value': 0,
#     'BMS_ERROR_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_ERROR_STATUS_start_bit': 77,
#     'BMS_ERROR_STATUS_len': '3'},
#    'BMS_HIGH_VOLTAGE_2': {'BMS_HIGH_VOLTAGE_2_value': 0,
#     'BMS_HIGH_VOLTAGE_2_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_VOLTAGE_2_start_bit': 80,
#     'BMS_HIGH_VOLTAGE_2_len': '13'},
#    'BMS_HIGH_VOLTAGE_3': {'BMS_HIGH_VOLTAGE_3_value': 0,
#     'BMS_HIGH_VOLTAGE_3_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_VOLTAGE_3_start_bit': 96,
#     'BMS_HIGH_VOLTAGE_3_len': '13'},
#    'BMS_HIGH_VOLTAGE_4': {'BMS_HIGH_VOLTAGE_4_value': 0,
#     'BMS_HIGH_VOLTAGE_4_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_VOLTAGE_4_start_bit': 112,
#     'BMS_HIGH_VOLTAGE_4_len': '13'},
#    'BMS_BATTERY_PACK_STATUS': {'BMS_BATTERY_PACK_STATUS_value': 0,
#     'BMS_BATTERY_PACK_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_PACK_STATUS_start_bit': 125,
#     'BMS_BATTERY_PACK_STATUS_len': '3'},
#    'BMS_HIGH_VOLTAGE_5': {'BMS_HIGH_VOLTAGE_5_value': 0,
#     'BMS_HIGH_VOLTAGE_5_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_VOLTAGE_5_start_bit': 128,
#     'BMS_HIGH_VOLTAGE_5_len': '13'},
#    'BMS_POSITIVE_CONTACTOR_STATE': {'BMS_POSITIVE_CONTACTOR_STATE_value': 0,
#     'BMS_POSITIVE_CONTACTOR_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_POSITIVE_CONTACTOR_STATE_start_bit': 141,
#     'BMS_POSITIVE_CONTACTOR_STATE_len': '3'},
#    'BMS_HIGH_VOLTAGE_6': {'BMS_HIGH_VOLTAGE_6_value': 0,
#     'BMS_HIGH_VOLTAGE_6_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_VOLTAGE_6_start_bit': 144,
#     'BMS_HIGH_VOLTAGE_6_len': '13'},
#    'BMS_FC_POSITIVE_CONTACTOR_STATE': {'BMS_FC_POSITIVE_CONTACTOR_STATE_value': 0,
#     'BMS_FC_POSITIVE_CONTACTOR_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_FC_POSITIVE_CONTACTOR_STATE_start_bit': 157,
#     'BMS_FC_POSITIVE_CONTACTOR_STATE_len': '3'},
#    'BMS_HIGH_VOLTAGE_7': {'BMS_HIGH_VOLTAGE_7_value': 0,
#     'BMS_HIGH_VOLTAGE_7_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_VOLTAGE_7_start_bit': 160,
#     'BMS_HIGH_VOLTAGE_7_len': '13'},
#    'BMS_CONTACTOR_STATUS': {'BMS_CONTACTOR_STATUS_value': 0,
#     'BMS_CONTACTOR_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CONTACTOR_STATUS_start_bit': 173,
#     'BMS_CONTACTOR_STATUS_len': '3'},
#    'BMS_BATTERY_TBATT': {'BMS_BATTERY_TBATT_value': 0,
#     'BMS_BATTERY_TBATT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_TBATT_start_bit': 192,
#     'BMS_BATTERY_TBATT_len': '12'},
#    'BMS_LVMSD_STS': {'BMS_LVMSD_STS_value': 0,
#     'BMS_LVMSD_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_LVMSD_STS_start_bit': 204,
#     'BMS_LVMSD_STS_len': '4'},
#    'BMS_BATTERY_PACK_VOLTAGE': {'BMS_BATTERY_PACK_VOLTAGE_value': 0,
#     'BMS_BATTERY_PACK_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_PACK_VOLTAGE_start_bit': 208,
#     'BMS_BATTERY_PACK_VOLTAGE_len': '13'},
#    'COOLANT_FLOW_DESIRED_HVBATT': {'COOLANT_FLOW_DESIRED_HVBATT_value': 0,
#     'COOLANT_FLOW_DESIRED_HVBATT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'COOLANT_FLOW_DESIRED_HVBATT_start_bit': 221,
#     'COOLANT_FLOW_DESIRED_HVBATT_len': '9'},
#    'BMS_FAN_SPD_REQ': {'BMS_FAN_SPD_REQ_value': 0,
#     'BMS_FAN_SPD_REQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_FAN_SPD_REQ_start_bit': 232,
#     'BMS_FAN_SPD_REQ_len': '7'},
#    'BMS_PUMP_SPD': {'BMS_PUMP_SPD_value': 0,
#     'BMS_PUMP_SPD_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_PUMP_SPD_start_bit': 240,
#     'BMS_PUMP_SPD_len': '13'},
#    'BMS_FC_CONTACTOR_STATUS': {'BMS_FC_CONTACTOR_STATUS_value': 0,
#     'BMS_FC_CONTACTOR_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_FC_CONTACTOR_STATUS_start_bit': 253,
#     'BMS_FC_CONTACTOR_STATUS_len': '3'},
#    'BMS_COOLANT_FLOW': {'BMS_COOLANT_FLOW_value': 0,
#     'BMS_COOLANT_FLOW_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_COOLANT_FLOW_start_bit': 256,
#     'BMS_COOLANT_FLOW_len': '10'},
#    'BMS_THERMAL_SYS_STATE': {'BMS_THERMAL_SYS_STATE_value': 0,
#     'BMS_THERMAL_SYS_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_THERMAL_SYS_STATE_start_bit': 266,
#     'BMS_THERMAL_SYS_STATE_len': '4'},
#    'BMS_TARGET_SOC_TIMETOCHARGE': {'BMS_TARGET_SOC_TIMETOCHARGE_value': 0,
#     'BMS_TARGET_SOC_TIMETOCHARGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_TARGET_SOC_TIMETOCHARGE_start_bit': 272,
#     'BMS_TARGET_SOC_TIMETOCHARGE_len': '11'},
#    'BMS_CRASH_PYRO_FUSE_RESPONSE': {'BMS_CRASH_PYRO_FUSE_RESPONSE_value': 0,
#     'BMS_CRASH_PYRO_FUSE_RESPONSE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CRASH_PYRO_FUSE_RESPONSE_start_bit': 283,
#     'BMS_CRASH_PYRO_FUSE_RESPONSE_len': '4'},
#    'BMS_ISOLATION_FLT': {'BMS_ISOLATION_FLT_value': 0,
#     'BMS_ISOLATION_FLT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_ISOLATION_FLT_start_bit': 312,
#     'BMS_ISOLATION_FLT_len': '3'},
#    'BMS_CONTACTORWELD_STATUS': {'BMS_CONTACTORWELD_STATUS_value': 0,
#     'BMS_CONTACTORWELD_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CONTACTORWELD_STATUS_start_bit': 328,
#     'BMS_CONTACTORWELD_STATUS_len': '8'}},
#   'total_signals': 35},
#  'BMS2_FD_100': {'length': '64',
#   'cycle_time': '0.1',
#   'signals': {'BMS_BATTERY_INLET_COOLANT_TEMP': {'BMS_BATTERY_INLET_COOLANT_TEMP_value': 0,
#     'BMS_BATTERY_INLET_COOLANT_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_INLET_COOLANT_TEMP_start_bit': 0,
#     'BMS_BATTERY_INLET_COOLANT_TEMP_len': '11'},
#    'BMS_BATT_PRECONDITIONING_STA': {'BMS_BATT_PRECONDITIONING_STA_value': 0,
#     'BMS_BATT_PRECONDITIONING_STA_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATT_PRECONDITIONING_STA_start_bit': 11,
#     'BMS_BATT_PRECONDITIONING_STA_len': '2'},
#    'BMS_BATT_INLET_COOLANT_TEMP_REQ': {'BMS_BATT_INLET_COOLANT_TEMP_REQ_value': 0,
#     'BMS_BATT_INLET_COOLANT_TEMP_REQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATT_INLET_COOLANT_TEMP_REQ_start_bit': 16,
#     'BMS_BATT_INLET_COOLANT_TEMP_REQ_len': '11'},
#    'BMS_HIGH_TEMP_LIGHT_OP_TT': {'BMS_HIGH_TEMP_LIGHT_OP_TT_value': 0,
#     'BMS_HIGH_TEMP_LIGHT_OP_TT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HIGH_TEMP_LIGHT_OP_TT_start_bit': 27,
#     'BMS_HIGH_TEMP_LIGHT_OP_TT_len': '2'},
#    'BMS_HV_BATT_TT': {'BMS_HV_BATT_TT_value': 0,
#     'BMS_HV_BATT_TT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HV_BATT_TT_start_bit': 29,
#     'BMS_HV_BATT_TT_len': '2'},
#    'BMS_BATTERY_OUTLET_COOLANT_TEMP': {'BMS_BATTERY_OUTLET_COOLANT_TEMP_value': 0,
#     'BMS_BATTERY_OUTLET_COOLANT_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_OUTLET_COOLANT_TEMP_start_bit': 32,
#     'BMS_BATTERY_OUTLET_COOLANT_TEMP_len': '11'},
#    'BMS_CHARGING_STOP': {'BMS_CHARGING_STOP_value': 0,
#     'BMS_CHARGING_STOP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGING_STOP_start_bit': 47,
#     'BMS_CHARGING_STOP_len': '1'},
#    'BMS_AVE_ENERGY_CONS': {'BMS_AVE_ENERGY_CONS_value': 0,
#     'BMS_AVE_ENERGY_CONS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_AVE_ENERGY_CONS_start_bit': 48,
#     'BMS_AVE_ENERGY_CONS_len': '10'},
#    'BMS_SERVICE_LIGHT_TT': {'BMS_SERVICE_LIGHT_TT_value': 0,
#     'BMS_SERVICE_LIGHT_TT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_SERVICE_LIGHT_TT_start_bit': 58,
#     'BMS_SERVICE_LIGHT_TT_len': '2'},
#    'BMS_BATTERY_DISCONNECT_STATUS': {'BMS_BATTERY_DISCONNECT_STATUS_value': 0,
#     'BMS_BATTERY_DISCONNECT_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_DISCONNECT_STATUS_start_bit': 60,
#     'BMS_BATTERY_DISCONNECT_STATUS_len': '4'},
#    'BMS_BATTERY_INSTANT_ENERGY_CONS': {'BMS_BATTERY_INSTANT_ENERGY_CONS_value': 0,
#     'BMS_BATTERY_INSTANT_ENERGY_CONS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_INSTANT_ENERGY_CONS_start_bit': 64,
#     'BMS_BATTERY_INSTANT_ENERGY_CONS_len': '10'},
#    'BMS_B_COOLING_REQUEST': {'BMS_B_COOLING_REQUEST_value': 0,
#     'BMS_B_COOLING_REQUEST_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_B_COOLING_REQUEST_start_bit': 74,
#     'BMS_B_COOLING_REQUEST_len': '2'},
#    'BMS_CHARGING_STATUS': {'BMS_CHARGING_STATUS_value': 0,
#     'BMS_CHARGING_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGING_STATUS_start_bit': 76,
#     'BMS_CHARGING_STATUS_len': '4'},
#    'BMS_CHARGE_CURRENT_LIMIT': {'BMS_CHARGE_CURRENT_LIMIT_value': 0,
#     'BMS_CHARGE_CURRENT_LIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGE_CURRENT_LIMIT_start_bit': 80,
#     'BMS_CHARGE_CURRENT_LIMIT_len': '12'},
#    'BMS_CHARGE_VOLTAGE_LIMIT': {'BMS_CHARGE_VOLTAGE_LIMIT_value': 0,
#     'BMS_CHARGE_VOLTAGE_LIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGE_VOLTAGE_LIMIT_start_bit': 96,
#     'BMS_CHARGE_VOLTAGE_LIMIT_len': '13'},
#    'BMS_4WAY_VALVE_STATUS': {'BMS_4WAY_VALVE_STATUS_value': 0,
#     'BMS_4WAY_VALVE_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_4WAY_VALVE_STATUS_start_bit': 109,
#     'BMS_4WAY_VALVE_STATUS_len': '2'},
#    'BMS_ALIVE_STATUS': {'BMS_ALIVE_STATUS_value': 0,
#     'BMS_ALIVE_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_ALIVE_STATUS_start_bit': 111,
#     'BMS_ALIVE_STATUS_len': '1'},
#    'BMS_DISCHARGE_CURRENT_LIMIT': {'BMS_DISCHARGE_CURRENT_LIMIT_value': 0,
#     'BMS_DISCHARGE_CURRENT_LIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_DISCHARGE_CURRENT_LIMIT_start_bit': 112,
#     'BMS_DISCHARGE_CURRENT_LIMIT_len': '14'},
#    'BMS_BATTERY_PACK_ASOC': {'BMS_BATTERY_PACK_ASOC_value': 0,
#     'BMS_BATTERY_PACK_ASOC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_PACK_ASOC_start_bit': 126,
#     'BMS_BATTERY_PACK_ASOC_len': '10'},
#    'BMS_BATTERY_MAX_CELL_VOLTAGE': {'BMS_BATTERY_MAX_CELL_VOLTAGE_value': 0,
#     'BMS_BATTERY_MAX_CELL_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_MAX_CELL_VOLTAGE_start_bit': 136,
#     'BMS_BATTERY_MAX_CELL_VOLTAGE_len': '13'},
#    'BMS_CHARGE_POWER_AVAILABLE_10': {'BMS_CHARGE_POWER_AVAILABLE_10_value': 0,
#     'BMS_CHARGE_POWER_AVAILABLE_10_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGE_POWER_AVAILABLE_10_start_bit': 149,
#     'BMS_CHARGE_POWER_AVAILABLE_10_len': '11'},
#    'BMS_BATTERY_MIN_CELL_VOLTAGE': {'BMS_BATTERY_MIN_CELL_VOLTAGE_value': 0,
#     'BMS_BATTERY_MIN_CELL_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_MIN_CELL_VOLTAGE_start_bit': 160,
#     'BMS_BATTERY_MIN_CELL_VOLTAGE_len': '13'},
#    'BMS_CHARGE_POWER_AVAILABLE_5': {'BMS_CHARGE_POWER_AVAILABLE_5_value': 0,
#     'BMS_CHARGE_POWER_AVAILABLE_5_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGE_POWER_AVAILABLE_5_start_bit': 173,
#     'BMS_CHARGE_POWER_AVAILABLE_5_len': '11'},
#    'BMS_BATTERY_MAX_TEMPERATURE': {'BMS_BATTERY_MAX_TEMPERATURE_value': 0,
#     'BMS_BATTERY_MAX_TEMPERATURE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_MAX_TEMPERATURE_start_bit': 184,
#     'BMS_BATTERY_MAX_TEMPERATURE_len': '12'},
#    'BMS_DISCHARGE_POWER_AVAILABLE_5': {'BMS_DISCHARGE_POWER_AVAILABLE_5_value': 0,
#     'BMS_DISCHARGE_POWER_AVAILABLE_5_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_DISCHARGE_POWER_AVAILABLE_5_start_bit': 196,
#     'BMS_DISCHARGE_POWER_AVAILABLE_5_len': '12'},
#    'BMS_AC_CHARGING_CYCLE': {'BMS_AC_CHARGING_CYCLE_value': 0,
#     'BMS_AC_CHARGING_CYCLE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_AC_CHARGING_CYCLE_start_bit': 208,
#     'BMS_AC_CHARGING_CYCLE_len': '16'},
#    'BMS_CHARGING_HRS_ELAPSED_LIFE': {'BMS_CHARGING_HRS_ELAPSED_LIFE_value': 0,
#     'BMS_CHARGING_HRS_ELAPSED_LIFE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGING_HRS_ELAPSED_LIFE_start_bit': 224,
#     'BMS_CHARGING_HRS_ELAPSED_LIFE_len': '17'},
#    'BMS_CHARGINGSTOP_REASON': {'BMS_CHARGINGSTOP_REASON_value': 0,
#     'BMS_CHARGINGSTOP_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGINGSTOP_REASON_start_bit': 241,
#     'BMS_CHARGINGSTOP_REASON_len': '6'},
#    'BMS_DISCHARGE_POWER_AVAILABLE_10': {'BMS_DISCHARGE_POWER_AVAILABLE_10_value': 0,
#     'BMS_DISCHARGE_POWER_AVAILABLE_10_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_DISCHARGE_POWER_AVAILABLE_10_start_bit': 248,
#     'BMS_DISCHARGE_POWER_AVAILABLE_10_len': '12'},
#    'BMS_DISCHARGING_ELAPSED_LIFE': {'BMS_DISCHARGING_ELAPSED_LIFE_value': 0,
#     'BMS_DISCHARGING_ELAPSED_LIFE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_DISCHARGING_ELAPSED_LIFE_start_bit': 272,
#     'BMS_DISCHARGING_ELAPSED_LIFE_len': '17'},
#    'BMS_L1_ERROR_REASON': {'BMS_L1_ERROR_REASON_value': 0,
#     'BMS_L1_ERROR_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_L1_ERROR_REASON_start_bit': 289,
#     'BMS_L1_ERROR_REASON_len': '6'},
#    'BMS_SOF': {'BMS_SOF_value': 0,
#     'BMS_SOF_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_SOF_start_bit': 296,
#     'BMS_SOF_len': '8'},
#    'BMS_DISCHARGE_POWER_AVAILABLE_30': {'BMS_DISCHARGE_POWER_AVAILABLE_30_value': 0,
#     'BMS_DISCHARGE_POWER_AVAILABLE_30_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_DISCHARGE_POWER_AVAILABLE_30_start_bit': 304,
#     'BMS_DISCHARGE_POWER_AVAILABLE_30_len': '12'},
#    'BMS_BATTERY_MIN_TEMPERATURE': {'BMS_BATTERY_MIN_TEMPERATURE_value': 0,
#     'BMS_BATTERY_MIN_TEMPERATURE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_MIN_TEMPERATURE_start_bit': 316,
#     'BMS_BATTERY_MIN_TEMPERATURE_len': '12'},
#    'BMS_COUNT_DC_CHARGING_CYCLES': {'BMS_COUNT_DC_CHARGING_CYCLES_value': 0,
#     'BMS_COUNT_DC_CHARGING_CYCLES_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_COUNT_DC_CHARGING_CYCLES_start_bit': 328,
#     'BMS_COUNT_DC_CHARGING_CYCLES_len': '16'},
#    'BMS_TIME_TO_CHARGE': {'BMS_TIME_TO_CHARGE_value': 0,
#     'BMS_TIME_TO_CHARGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_TIME_TO_CHARGE_start_bit': 352,
#     'BMS_TIME_TO_CHARGE_len': '11'},
#    'BMS_CHARGE_POWER_AVAILABLE_30': {'BMS_CHARGE_POWER_AVAILABLE_30_value': 0,
#     'BMS_CHARGE_POWER_AVAILABLE_30_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_CHARGE_POWER_AVAILABLE_30_start_bit': 368,
#     'BMS_CHARGE_POWER_AVAILABLE_30_len': '11'},
#    'BMS_BATTERY_PACK_RSOC': {'BMS_BATTERY_PACK_RSOC_value': 0,
#     'BMS_BATTERY_PACK_RSOC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_PACK_RSOC_start_bit': 384,
#     'BMS_BATTERY_PACK_RSOC_len': '10'},
#    'BMS_L2_ERROR_REASON': {'BMS_L2_ERROR_REASON_value': 0,
#     'BMS_L2_ERROR_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_L2_ERROR_REASON_start_bit': 394,
#     'BMS_L2_ERROR_REASON_len': '6'},
#    'BMS_BATTERY_PACK_SOE': {'BMS_BATTERY_PACK_SOE_value': 0,
#     'BMS_BATTERY_PACK_SOE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_PACK_SOE_start_bit': 400,
#     'BMS_BATTERY_PACK_SOE_len': '10'},
#    'BMS_L3_ERROR_REASON': {'BMS_L3_ERROR_REASON_value': 0,
#     'BMS_L3_ERROR_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_L3_ERROR_REASON_start_bit': 410,
#     'BMS_L3_ERROR_REASON_len': '6'},
#    'BMS_ACTUAL_BATT_HEATER_PWR': {'BMS_ACTUAL_BATT_HEATER_PWR_value': 0,
#     'BMS_ACTUAL_BATT_HEATER_PWR_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_ACTUAL_BATT_HEATER_PWR_start_bit': 416,
#     'BMS_ACTUAL_BATT_HEATER_PWR_len': '10'},
#    'BMS_L4_ERROR_REASON': {'BMS_L4_ERROR_REASON_value': 0,
#     'BMS_L4_ERROR_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_L4_ERROR_REASON_start_bit': 426,
#     'BMS_L4_ERROR_REASON_len': '6'},
#    'BMS_BATTERY_PACK_SOH': {'BMS_BATTERY_PACK_SOH_value': 0,
#     'BMS_BATTERY_PACK_SOH_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATTERY_PACK_SOH_start_bit': 432,
#     'BMS_BATTERY_PACK_SOH_len': '10'},
#    'BMS_DISCHARGE_VOLTAGE_LIMIT': {'BMS_DISCHARGE_VOLTAGE_LIMIT_value': 0,
#     'BMS_DISCHARGE_VOLTAGE_LIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_DISCHARGE_VOLTAGE_LIMIT_start_bit': 448,
#     'BMS_DISCHARGE_VOLTAGE_LIMIT_len': '13'}},
#   'total_signals': 45},
#  'BMS3_FD_100': {'length': '64',
#   'cycle_time': '0.1',
#   'signals': {'BMS_MAX_PRECHARGE_CURRENTLIMIT': {'BMS_MAX_PRECHARGE_CURRENTLIMIT_value': 0,
#     'BMS_MAX_PRECHARGE_CURRENTLIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_MAX_PRECHARGE_CURRENTLIMIT_start_bit': 0,
#     'BMS_MAX_PRECHARGE_CURRENTLIMIT_len': '13'},
#    'BMS_ISOLATION_FAULT_TYPE': {'BMS_ISOLATION_FAULT_TYPE_value': 0,
#     'BMS_ISOLATION_FAULT_TYPE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_ISOLATION_FAULT_TYPE_start_bit': 13,
#     'BMS_ISOLATION_FAULT_TYPE_len': '3'},
#    'BMS_MAX_PRECHARGE_VOLTAGE': {'BMS_MAX_PRECHARGE_VOLTAGE_value': 0,
#     'BMS_MAX_PRECHARGE_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_MAX_PRECHARGE_VOLTAGE_start_bit': 16,
#     'BMS_MAX_PRECHARGE_VOLTAGE_len': '13'},
#    'BMS_ISOLATION_MON_STS': {'BMS_ISOLATION_MON_STS_value': 0,
#     'BMS_ISOLATION_MON_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_ISOLATION_MON_STS_start_bit': 29,
#     'BMS_ISOLATION_MON_STS_len': '3'},
#    'BMS_BATT_AH': {'BMS_BATT_AH_value': 0,
#     'BMS_BATT_AH_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_BATT_AH_start_bit': 32,
#     'BMS_BATT_AH_len': '11'},
#    'BMS_HV_BATT_DISCHARGE_STS': {'BMS_HV_BATT_DISCHARGE_STS_value': 0,
#     'BMS_HV_BATT_DISCHARGE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HV_BATT_DISCHARGE_STS_start_bit': 43,
#     'BMS_HV_BATT_DISCHARGE_STS_len': '2'},
#    'BMS_THERMAL_RUNAWAY_IND': {'BMS_THERMAL_RUNAWAY_IND_value': 0,
#     'BMS_THERMAL_RUNAWAY_IND_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_THERMAL_RUNAWAY_IND_start_bit': 45,
#     'BMS_THERMAL_RUNAWAY_IND_len': '2'},
#    'BMS_REGEN_DISABLE_REQ': {'BMS_REGEN_DISABLE_REQ_value': 0,
#     'BMS_REGEN_DISABLE_REQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_REGEN_DISABLE_REQ_start_bit': 47,
#     'BMS_REGEN_DISABLE_REQ_len': '1'},
#    'BMS_MIN_PRECHARGE_VOLTAGE': {'BMS_MIN_PRECHARGE_VOLTAGE_value': 0,
#     'BMS_MIN_PRECHARGE_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_MIN_PRECHARGE_VOLTAGE_start_bit': 48,
#     'BMS_MIN_PRECHARGE_VOLTAGE_len': '13'},
#    'BMS_L2_DERATE_LEVEL': {'BMS_L2_DERATE_LEVEL_value': 0,
#     'BMS_L2_DERATE_LEVEL_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_L2_DERATE_LEVEL_start_bit': 61,
#     'BMS_L2_DERATE_LEVEL_len': '3'},
#    'BMS_MIN_VOLTAGE_LIMIT': {'BMS_MIN_VOLTAGE_LIMIT_value': 0,
#     'BMS_MIN_VOLTAGE_LIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_MIN_VOLTAGE_LIMIT_start_bit': 64,
#     'BMS_MIN_VOLTAGE_LIMIT_len': '13'},
#    'BMS_MAX_SINGLECELLCHRG_VOLTLIMIT': {'BMS_MAX_SINGLECELLCHRG_VOLTLIMIT_value': 0,
#     'BMS_MAX_SINGLECELLCHRG_VOLTLIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_MAX_SINGLECELLCHRG_VOLTLIMIT_start_bit': 80,
#     'BMS_MAX_SINGLECELLCHRG_VOLTLIMIT_len': '13'},
#    'BMS_MAX_VOLTAGE_LIMIT': {'BMS_MAX_VOLTAGE_LIMIT_value': 0,
#     'BMS_MAX_VOLTAGE_LIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_MAX_VOLTAGE_LIMIT_start_bit': 96,
#     'BMS_MAX_VOLTAGE_LIMIT_len': '13'},
#    'BMS_PEAK_CHARGE_CURRENTLIMIT': {'BMS_PEAK_CHARGE_CURRENTLIMIT_value': 0,
#     'BMS_PEAK_CHARGE_CURRENTLIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_PEAK_CHARGE_CURRENTLIMIT_start_bit': 112,
#     'BMS_PEAK_CHARGE_CURRENTLIMIT_len': '12'},
#    'BMS_THERMAL_ERROR_STS': {'BMS_THERMAL_ERROR_STS_value': 0,
#     'BMS_THERMAL_ERROR_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_THERMAL_ERROR_STS_start_bit': 124,
#     'BMS_THERMAL_ERROR_STS_len': '4'},
#    'BMS_PEAK_DISCHARGE_CURRENTLIMIT': {'BMS_PEAK_DISCHARGE_CURRENTLIMIT_value': 0,
#     'BMS_PEAK_DISCHARGE_CURRENTLIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_PEAK_DISCHARGE_CURRENTLIMIT_start_bit': 128,
#     'BMS_PEAK_DISCHARGE_CURRENTLIMIT_len': '14'},
#    'BMS_RECUP_CONT_CURRENTLIMIT': {'BMS_RECUP_CONT_CURRENTLIMIT_value': 0,
#     'BMS_RECUP_CONT_CURRENTLIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_RECUP_CONT_CURRENTLIMIT_start_bit': 144,
#     'BMS_RECUP_CONT_CURRENTLIMIT_len': '12'},
#    'BMS_RECUP_PEAK_CURRENTLIMIT': {'BMS_RECUP_PEAK_CURRENTLIMIT_value': 0,
#     'BMS_RECUP_PEAK_CURRENTLIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_RECUP_PEAK_CURRENTLIMIT_start_bit': 160,
#     'BMS_RECUP_PEAK_CURRENTLIMIT_len': '12'},
#    'BMS_RECUP_POWERAVAILABLE_10': {'BMS_RECUP_POWERAVAILABLE_10_value': 0,
#     'BMS_RECUP_POWERAVAILABLE_10_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_RECUP_POWERAVAILABLE_10_start_bit': 176,
#     'BMS_RECUP_POWERAVAILABLE_10_len': '11'},
#    'BMS_HV_BATT_ERROR': {'BMS_HV_BATT_ERROR_value': 0,
#     'BMS_HV_BATT_ERROR_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_HV_BATT_ERROR_start_bit': 187,
#     'BMS_HV_BATT_ERROR_len': '5'},
#    'BMS_RECUP_POWERAVAILABLE_5': {'BMS_RECUP_POWERAVAILABLE_5_value': 0,
#     'BMS_RECUP_POWERAVAILABLE_5_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_RECUP_POWERAVAILABLE_5_start_bit': 192,
#     'BMS_RECUP_POWERAVAILABLE_5_len': '11'},
#    'BMS_RECUP_POWERAVAILABLE_30': {'BMS_RECUP_POWERAVAILABLE_30_value': 0,
#     'BMS_RECUP_POWERAVAILABLE_30_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_RECUP_POWERAVAILABLE_30_start_bit': 208,
#     'BMS_RECUP_POWERAVAILABLE_30_len': '11'},
#    'BMS_RECUP_VOLTAGE_LIMIT': {'BMS_RECUP_VOLTAGE_LIMIT_value': 0,
#     'BMS_RECUP_VOLTAGE_LIMIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_RECUP_VOLTAGE_LIMIT_start_bit': 224,
#     'BMS_RECUP_VOLTAGE_LIMIT_len': '13'},
#    'BMS_PTC_HEATER_CURRENT': {'BMS_PTC_HEATER_CURRENT_value': 0,
#     'BMS_PTC_HEATER_CURRENT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_PTC_HEATER_CURRENT_start_bit': 240,
#     'BMS_PTC_HEATER_CURRENT_len': '11'},
#    'BMS_PTC_HEATER_VOLTAGE': {'BMS_PTC_HEATER_VOLTAGE_value': 0,
#     'BMS_PTC_HEATER_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_PTC_HEATER_VOLTAGE_start_bit': 256,
#     'BMS_PTC_HEATER_VOLTAGE_len': '13'},
#    'BMS_ISOLATION_RESISTANCE': {'BMS_ISOLATION_RESISTANCE_value': 0,
#     'BMS_ISOLATION_RESISTANCE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_ISOLATION_RESISTANCE_start_bit': 272,
#     'BMS_ISOLATION_RESISTANCE_len': '13'},
#    'BMS_COOLANT_TEMP_SER_REQ': {'BMS_COOLANT_TEMP_SER_REQ_value': 0,
#     'BMS_COOLANT_TEMP_SER_REQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_COOLANT_TEMP_SER_REQ_start_bit': 288,
#     'BMS_COOLANT_TEMP_SER_REQ_len': '11'},
#    'BMS_REVIVEMODE_COUNT': {'BMS_REVIVEMODE_COUNT_value': 0,
#     'BMS_REVIVEMODE_COUNT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_REVIVEMODE_COUNT_start_bit': 304,
#     'BMS_REVIVEMODE_COUNT_len': '8'},
#    'BMS_LIFETIME_ENERGY_AC_CHRG': {'BMS_LIFETIME_ENERGY_AC_CHRG_value': 0,
#     'BMS_LIFETIME_ENERGY_AC_CHRG_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_LIFETIME_ENERGY_AC_CHRG_start_bit': 328,
#     'BMS_LIFETIME_ENERGY_AC_CHRG_len': '19'},
#    'BMS_LIFETIME_ENERGY_CONS': {'BMS_LIFETIME_ENERGY_CONS_value': 0,
#     'BMS_LIFETIME_ENERGY_CONS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_LIFETIME_ENERGY_CONS_start_bit': 352,
#     'BMS_LIFETIME_ENERGY_CONS_len': '19'},
#    'BMS_LIFETIME_ENERGY_DC_CHRG': {'BMS_LIFETIME_ENERGY_DC_CHRG_value': 0,
#     'BMS_LIFETIME_ENERGY_DC_CHRG_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_LIFETIME_ENERGY_DC_CHRG_start_bit': 376,
#     'BMS_LIFETIME_ENERGY_DC_CHRG_len': '19'},
#    'BMS_LIFETIME_ENERGY_RECUP': {'BMS_LIFETIME_ENERGY_RECUP_value': 0,
#     'BMS_LIFETIME_ENERGY_RECUP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_LIFETIME_ENERGY_RECUP_start_bit': 400,
#     'BMS_LIFETIME_ENERGY_RECUP_len': '19'}},
#   'total_signals': 32},
#  'BMS_CANNM': {'length': '8',
#   'cycle_time': '0.0',
#   'signals': {'BMS_WAKEUP_REASON': {'BMS_WAKEUP_REASON_value': 0,
#     'BMS_WAKEUP_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BMS_WAKEUP_REASON_start_bit': 16,
#     'BMS_WAKEUP_REASON_len': '8'}},
#   'total_signals': 1},
#  'CCM11_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'LIFE_TIMER_POW_CONS_BATT_COOLING': {'LIFE_TIMER_POW_CONS_BATT_COOLING_value': 0,
#     'LIFE_TIMER_POW_CONS_BATT_COOLING_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'LIFE_TIMER_POW_CONS_BATT_COOLING_start_bit': 0,
#     'LIFE_TIMER_POW_CONS_BATT_COOLING_len': '21'},
#    'LIFE_TIMER_POWER_CONS_HVAC': {'LIFE_TIMER_POWER_CONS_HVAC_value': 0,
#     'LIFE_TIMER_POWER_CONS_HVAC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'LIFE_TIMER_POWER_CONS_HVAC_start_bit': 21,
#     'LIFE_TIMER_POWER_CONS_HVAC_len': '21'}},
#   'total_signals': 2},
#  'CCM1_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'INCAR_TEMP': {'INCAR_TEMP_value': 0,
#     'INCAR_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'INCAR_TEMP_start_bit': 0,
#     'INCAR_TEMP_len': '8'},
#    'AQI_VALUE': {'AQI_VALUE_value': 0,
#     'AQI_VALUE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AQI_VALUE_start_bit': 8,
#     'AQI_VALUE_len': '8'},
#    'DISP_MODE': {'DISP_MODE_value': 0,
#     'DISP_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DISP_MODE_start_bit': 16,
#     'DISP_MODE_len': '4'},
#    'DISP_BLOWER': {'DISP_BLOWER_value': 0,
#     'DISP_BLOWER_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DISP_BLOWER_start_bit': 20,
#     'DISP_BLOWER_len': '4'},
#    'FRONT_RIGHT_SET_TEMP': {'FRONT_RIGHT_SET_TEMP_value': 0,
#     'FRONT_RIGHT_SET_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'FRONT_RIGHT_SET_TEMP_start_bit': 24,
#     'FRONT_RIGHT_SET_TEMP_len': '8'},
#    'FRONT_LEFT_SET_TEMP': {'FRONT_LEFT_SET_TEMP_value': 0,
#     'FRONT_LEFT_SET_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'FRONT_LEFT_SET_TEMP_start_bit': 32,
#     'FRONT_LEFT_SET_TEMP_len': '8'},
#    'FATC_AUTO': {'FATC_AUTO_value': 0,
#     'FATC_AUTO_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'FATC_AUTO_start_bit': 40,
#     'FATC_AUTO_len': '2'},
#    'DISP_DUAL': {'DISP_DUAL_value': 0,
#     'DISP_DUAL_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DISP_DUAL_start_bit': 42,
#     'DISP_DUAL_len': '2'},
#    'DISP_OFF': {'DISP_OFF_value': 0,
#     'DISP_OFF_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DISP_OFF_start_bit': 44,
#     'DISP_OFF_len': '2'},
#    'FRESH_RECIRC': {'FRESH_RECIRC_value': 0,
#     'FRESH_RECIRC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'FRESH_RECIRC_start_bit': 46,
#     'FRESH_RECIRC_len': '2'},
#    'STS_IONIZER': {'STS_IONIZER_value': 0,
#     'STS_IONIZER_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_IONIZER_start_bit': 48,
#     'STS_IONIZER_len': '1'},
#    'DISP_AC': {'DISP_AC_value': 0,
#     'DISP_AC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DISP_AC_start_bit': 49,
#     'DISP_AC_len': '2'},
#    'STS_REAR_AC': {'STS_REAR_AC_value': 0,
#     'STS_REAR_AC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_REAR_AC_start_bit': 51,
#     'STS_REAR_AC_len': '1'}},
#   'total_signals': 13},
#  'CCM2_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'DISCHARGE_LINE_PRESSURE': {'DISCHARGE_LINE_PRESSURE_value': 0,
#     'DISCHARGE_LINE_PRESSURE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DISCHARGE_LINE_PRESSURE_start_bit': 0,
#     'DISCHARGE_LINE_PRESSURE_len': '9'},
#    'DEFOG_STS': {'DEFOG_STS_value': 0,
#     'DEFOG_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DEFOG_STS_start_bit': 12,
#     'DEFOG_STS_len': '1'},
#    'REMOTE_HVAC_REQ_CCM': {'REMOTE_HVAC_REQ_CCM_value': 0,
#     'REMOTE_HVAC_REQ_CCM_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'REMOTE_HVAC_REQ_CCM_start_bit': 13,
#     'REMOTE_HVAC_REQ_CCM_len': '1'},
#    'AUTO_DEFROST': {'AUTO_DEFROST_value': 0,
#     'AUTO_DEFROST_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AUTO_DEFROST_start_bit': 46,
#     'AUTO_DEFROST_len': '1'},
#    'CONSOLE_FLOW_OFF_STS': {'CONSOLE_FLOW_OFF_STS_value': 0,
#     'CONSOLE_FLOW_OFF_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CONSOLE_FLOW_OFF_STS_start_bit': 47,
#     'CONSOLE_FLOW_OFF_STS_len': '1'}},
#   'total_signals': 5},
#  'CCM3_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'AC_POWER_CONSUMPTION_CCM': {'AC_POWER_CONSUMPTION_CCM_value': 0,
#     'AC_POWER_CONSUMPTION_CCM_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AC_POWER_CONSUMPTION_CCM_start_bit': 0,
#     'AC_POWER_CONSUMPTION_CCM_len': '8'},
#    'CABIN_HEATER_POWER_CONSUMPTION': {'CABIN_HEATER_POWER_CONSUMPTION_value': 0,
#     'CABIN_HEATER_POWER_CONSUMPTION_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CABIN_HEATER_POWER_CONSUMPTION_start_bit': 16,
#     'CABIN_HEATER_POWER_CONSUMPTION_len': '8'},
#    'COMPRESSURE_SPD': {'COMPRESSURE_SPD_value': 0,
#     'COMPRESSURE_SPD_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'COMPRESSURE_SPD_start_bit': 24,
#     'COMPRESSURE_SPD_len': '16'},
#    'STS_ACC': {'STS_ACC_value': 0,
#     'STS_ACC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_ACC_start_bit': 51,
#     'STS_ACC_len': '1'}},
#   'total_signals': 4},
#  'CCM4_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'SH_ACTUAL': {'SH_ACTUAL_value': 0,
#     'SH_ACTUAL_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SH_ACTUAL_start_bit': 0,
#     'SH_ACTUAL_len': '11'},
#    'SH_HEAT': {'SH_HEAT_value': 0,
#     'SH_HEAT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SH_HEAT_start_bit': 11,
#     'SH_HEAT_len': '11'},
#    'RAD_FAN_REQ': {'RAD_FAN_REQ_value': 0,
#     'RAD_FAN_REQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'RAD_FAN_REQ_start_bit': 49,
#     'RAD_FAN_REQ_len': '1'}},
#   'total_signals': 3},
#  'CCM5_TEST_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'COMP_TEMP_CAN': {'COMP_TEMP_CAN_value': 0,
#     'COMP_TEMP_CAN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'COMP_TEMP_CAN_start_bit': 32,
#     'COMP_TEMP_CAN_len': '8'},
#    'EVAP_TEMP': {'EVAP_TEMP_value': 0,
#     'EVAP_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EVAP_TEMP_start_bit': 40,
#     'EVAP_TEMP_len': '12'}},
#   'total_signals': 2},
#  'CCM6_TEST_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'PTC_TEMP2_CAN': {'PTC_TEMP2_CAN_value': 0,
#     'PTC_TEMP2_CAN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PTC_TEMP2_CAN_start_bit': 8,
#     'PTC_TEMP2_CAN_len': '8'},
#    'PTC_TEMP3_CAN': {'PTC_TEMP3_CAN_value': 0,
#     'PTC_TEMP3_CAN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PTC_TEMP3_CAN_start_bit': 16,
#     'PTC_TEMP3_CAN_len': '8'},
#    'EXV_CONTROL_FB': {'EXV_CONTROL_FB_value': 0,
#     'EXV_CONTROL_FB_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EXV_CONTROL_FB_start_bit': 48,
#     'EXV_CONTROL_FB_len': '7'},
#    'AIR_INTAKE_ACTUATOR_FBV': {'AIR_INTAKE_ACTUATOR_FBV_value': 0,
#     'AIR_INTAKE_ACTUATOR_FBV_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AIR_INTAKE_ACTUATOR_FBV_start_bit': 56,
#     'AIR_INTAKE_ACTUATOR_FBV_len': '6'}},
#   'total_signals': 4},
#  'CCM7_TEST_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'SUCTION_LINE_PRESSURE': {'SUCTION_LINE_PRESSURE_value': 0,
#     'SUCTION_LINE_PRESSURE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SUCTION_LINE_PRESSURE_start_bit': 8,
#     'SUCTION_LINE_PRESSURE_len': '8'},
#    'SUCTION_LINE_TEMP': {'SUCTION_LINE_TEMP_value': 0,
#     'SUCTION_LINE_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SUCTION_LINE_TEMP_start_bit': 48,
#     'SUCTION_LINE_TEMP_len': '11'}},
#   'total_signals': 2},
#  'CCM8_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'PSM_CCM_STS': {'PSM_CCM_STS_value': 0,
#     'PSM_CCM_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PSM_CCM_STS_start_bit': 9,
#     'PSM_CCM_STS_len': '1'},
#    'DISP_MODE_CODRIVER': {'DISP_MODE_CODRIVER_value': 0,
#     'DISP_MODE_CODRIVER_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DISP_MODE_CODRIVER_start_bit': 10,
#     'DISP_MODE_CODRIVER_len': '4'},
#    'AQI_SENSOR_VALUE': {'AQI_SENSOR_VALUE_value': 0,
#     'AQI_SENSOR_VALUE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AQI_SENSOR_VALUE_start_bit': 16,
#     'AQI_SENSOR_VALUE_len': '13'},
#    'AQI_SENSOR_STATUS': {'AQI_SENSOR_STATUS_value': 0,
#     'AQI_SENSOR_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AQI_SENSOR_STATUS_start_bit': 29,
#     'AQI_SENSOR_STATUS_len': '1'},
#    'DRIVER_MODE': {'DRIVER_MODE_value': 0,
#     'DRIVER_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DRIVER_MODE_start_bit': 33,
#     'DRIVER_MODE_len': '1'},
#    'MAX_AC_STS': {'MAX_AC_STS_value': 0,
#     'MAX_AC_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'MAX_AC_STS_start_bit': 34,
#     'MAX_AC_STS_len': '1'},
#    'MEM_DISP': {'MEM_DISP_value': 0,
#     'MEM_DISP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'MEM_DISP_start_bit': 36,
#     'MEM_DISP_len': '4'},
#    'PET_MODE_STS': {'PET_MODE_STS_value': 0,
#     'PET_MODE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PET_MODE_STS_start_bit': 40,
#     'PET_MODE_STS_len': '1'},
#    'CAMP_MODE_STS': {'CAMP_MODE_STS_value': 0,
#     'CAMP_MODE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CAMP_MODE_STS_start_bit': 41,
#     'CAMP_MODE_STS_len': '1'},
#    'ECON_MODE_STS': {'ECON_MODE_STS_value': 0,
#     'ECON_MODE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ECON_MODE_STS_start_bit': 42,
#     'ECON_MODE_STS_len': '1'},
#    'CLEAR_VIEW_STS': {'CLEAR_VIEW_STS_value': 0,
#     'CLEAR_VIEW_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CLEAR_VIEW_STS_start_bit': 43,
#     'CLEAR_VIEW_STS_len': '1'},
#    'PRECOOL_WAKEUP_STS': {'PRECOOL_WAKEUP_STS_value': 0,
#     'PRECOOL_WAKEUP_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PRECOOL_WAKEUP_STS_start_bit': 44,
#     'PRECOOL_WAKEUP_STS_len': '1'},
#    'SMART_SCREEN_INPUT_7_STS': {'SMART_SCREEN_INPUT_7_STS_value': 0,
#     'SMART_SCREEN_INPUT_7_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SMART_SCREEN_INPUT_7_STS_start_bit': 45,
#     'SMART_SCREEN_INPUT_7_STS_len': '1'},
#    'SMART_SCREEN_INPUT_8_STS': {'SMART_SCREEN_INPUT_8_STS_value': 0,
#     'SMART_SCREEN_INPUT_8_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SMART_SCREEN_INPUT_8_STS_start_bit': 46,
#     'SMART_SCREEN_INPUT_8_STS_len': '1'},
#    'KEEP_MODE_STS': {'KEEP_MODE_STS_value': 0,
#     'KEEP_MODE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'KEEP_MODE_STS_start_bit': 47,
#     'KEEP_MODE_STS_len': '1'},
#    'CABIN_COOLING_STATUS': {'CABIN_COOLING_STATUS_value': 0,
#     'CABIN_COOLING_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CABIN_COOLING_STATUS_start_bit': 50,
#     'CABIN_COOLING_STATUS_len': '1'}},
#   'total_signals': 16},
#  'CCM9_200': {'length': '8',
#   'cycle_time': '0.2',
#   'signals': {'COMPRESSOR_ON_REQUEST': {'COMPRESSOR_ON_REQUEST_value': 0,
#     'COMPRESSOR_ON_REQUEST_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'COMPRESSOR_ON_REQUEST_start_bit': 7,
#     'COMPRESSOR_ON_REQUEST_len': '1'},
#    'PTC_HEATER_HV_VOLTAGE': {'PTC_HEATER_HV_VOLTAGE_value': 0,
#     'PTC_HEATER_HV_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PTC_HEATER_HV_VOLTAGE_start_bit': 8,
#     'PTC_HEATER_HV_VOLTAGE_len': '13'},
#    'AC_COMPRESSOR_HV_VOLTAGE': {'AC_COMPRESSOR_HV_VOLTAGE_value': 0,
#     'AC_COMPRESSOR_HV_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AC_COMPRESSOR_HV_VOLTAGE_start_bit': 21,
#     'AC_COMPRESSOR_HV_VOLTAGE_len': '13'},
#    'CCM_FAULT_STATE': {'CCM_FAULT_STATE_value': 0,
#     'CCM_FAULT_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CCM_FAULT_STATE_start_bit': 38,
#     'CCM_FAULT_STATE_len': '2'},
#    'BATT_COOLING_STS': {'BATT_COOLING_STS_value': 0,
#     'BATT_COOLING_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BATT_COOLING_STS_start_bit': 40,
#     'BATT_COOLING_STS_len': '2'},
#    'MAX_DEFROST': {'MAX_DEFROST_value': 0,
#     'MAX_DEFROST_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'MAX_DEFROST_start_bit': 42,
#     'MAX_DEFROST_len': '1'}},
#   'total_signals': 6},
#  'CCM_CANNM': {'length': '8',
#   'cycle_time': '0.0',
#   'signals': {'ACTIVE_WAKEUP_BIT': {'ACTIVE_WAKEUP_BIT_value': 0,
#     'ACTIVE_WAKEUP_BIT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ACTIVE_WAKEUP_BIT_start_bit': 12,
#     'ACTIVE_WAKEUP_BIT_len': '1'},
#    'CCM_WAKEUP_REASON': {'CCM_WAKEUP_REASON_value': 0,
#     'CCM_WAKEUP_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CCM_WAKEUP_REASON_start_bit': 16,
#     'CCM_WAKEUP_REASON_len': '8'}},
#   'total_signals': 2},
#  'EPS1_FD_10': {'length': '64',
#   'cycle_time': '0.01',
#   'signals': {'STEERING_ABSOLUTE_ANGLE': {'STEERING_ABSOLUTE_ANGLE_value': 0,
#     'STEERING_ABSOLUTE_ANGLE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STEERING_ABSOLUTE_ANGLE_start_bit': 0,
#     'STEERING_ABSOLUTE_ANGLE_len': '16'},
#    'STEERING_ABSOLUTE_ANGLE_SPD': {'STEERING_ABSOLUTE_ANGLE_SPD_value': 0,
#     'STEERING_ABSOLUTE_ANGLE_SPD_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STEERING_ABSOLUTE_ANGLE_SPD_start_bit': 16,
#     'STEERING_ABSOLUTE_ANGLE_SPD_len': '8'},
#    'STS_SAS_CALIB': {'STS_SAS_CALIB_value': 0,
#     'STS_SAS_CALIB_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_SAS_CALIB_start_bit': 24,
#     'STS_SAS_CALIB_len': '1'},
#    'STS_SAS_FAILURE': {'STS_SAS_FAILURE_value': 0,
#     'STS_SAS_FAILURE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_SAS_FAILURE_start_bit': 25,
#     'STS_SAS_FAILURE_len': '1'},
#    'STS_EPS': {'STS_EPS_value': 0,
#     'STS_EPS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_EPS_start_bit': 26,
#     'STS_EPS_len': '1'},
#    'INDC_EPS': {'INDC_EPS_value': 0,
#     'INDC_EPS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'INDC_EPS_start_bit': 27,
#     'INDC_EPS_len': '1'},
#    'EPS_APA_CTRL_AVAILABLE': {'EPS_APA_CTRL_AVAILABLE_value': 0,
#     'EPS_APA_CTRL_AVAILABLE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_APA_CTRL_AVAILABLE_start_bit': 30,
#     'EPS_APA_CTRL_AVAILABLE_len': '2'},
#    'EPS_ANGLE_CTRL_OUT_TORQUE': {'EPS_ANGLE_CTRL_OUT_TORQUE_value': 0,
#     'EPS_ANGLE_CTRL_OUT_TORQUE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_ANGLE_CTRL_OUT_TORQUE_start_bit': 48,
#     'EPS_ANGLE_CTRL_OUT_TORQUE_len': '8'},
#    'EPS_DRIVER_INPUT_BOOST_TORQUE': {'EPS_DRIVER_INPUT_BOOST_TORQUE_value': 0,
#     'EPS_DRIVER_INPUT_BOOST_TORQUE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_DRIVER_INPUT_BOOST_TORQUE_start_bit': 64,
#     'EPS_DRIVER_INPUT_BOOST_TORQUE_len': '6'},
#    'EPS_DRV_ADV_CUS_MODE': {'EPS_DRV_ADV_CUS_MODE_value': 0,
#     'EPS_DRV_ADV_CUS_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_DRV_ADV_CUS_MODE_start_bit': 72,
#     'EPS_DRV_ADV_CUS_MODE_len': '4'},
#    'EPS_DRV_ADV_MODE_STS': {'EPS_DRV_ADV_MODE_STS_value': 0,
#     'EPS_DRV_ADV_MODE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_DRV_ADV_MODE_STS_start_bit': 76,
#     'EPS_DRV_ADV_MODE_STS_len': '2'},
#    'EPS_ADAS_FUNC_FAULT': {'EPS_ADAS_FUNC_FAULT_value': 0,
#     'EPS_ADAS_FUNC_FAULT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_ADAS_FUNC_FAULT_start_bit': 78,
#     'EPS_ADAS_FUNC_FAULT_len': '2'},
#    'EPS_DRIVER_INPUT_TRQ_BOOST_ACT': {'EPS_DRIVER_INPUT_TRQ_BOOST_ACT_value': 0,
#     'EPS_DRIVER_INPUT_TRQ_BOOST_ACT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_DRIVER_INPUT_TRQ_BOOST_ACT_start_bit': 95,
#     'EPS_DRIVER_INPUT_TRQ_BOOST_ACT_len': '1'},
#    'EPS_ANGLE_CTRL_STATUS': {'EPS_ANGLE_CTRL_STATUS_value': 0,
#     'EPS_ANGLE_CTRL_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_ANGLE_CTRL_STATUS_start_bit': 96,
#     'EPS_ANGLE_CTRL_STATUS_len': '2'},
#    'INF_DST_ERROR': {'INF_DST_ERROR_value': 0,
#     'INF_DST_ERROR_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'INF_DST_ERROR_start_bit': 99,
#     'INF_DST_ERROR_len': '1'},
#    'EPS_STR_WHL_TORQUE': {'EPS_STR_WHL_TORQUE_value': 0,
#     'EPS_STR_WHL_TORQUE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_STR_WHL_TORQUE_start_bit': 100,
#     'EPS_STR_WHL_TORQUE_len': '12'},
#    'EPS_EST_STR_WHL_ANGLE': {'EPS_EST_STR_WHL_ANGLE_value': 0,
#     'EPS_EST_STR_WHL_ANGLE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_EST_STR_WHL_ANGLE_start_bit': 128,
#     'EPS_EST_STR_WHL_ANGLE_len': '16'},
#    'EPS_MOTOR_RPM': {'EPS_MOTOR_RPM_value': 0,
#     'EPS_MOTOR_RPM_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_MOTOR_RPM_start_bit': 144,
#     'EPS_MOTOR_RPM_len': '12'},
#    'EPS_SHIMMY_COMPENSATION_FLAG': {'EPS_SHIMMY_COMPENSATION_FLAG_value': 0,
#     'EPS_SHIMMY_COMPENSATION_FLAG_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_SHIMMY_COMPENSATION_FLAG_start_bit': 159,
#     'EPS_SHIMMY_COMPENSATION_FLAG_len': '1'},
#    'EPS_ENERGY_CONSUMPTION': {'EPS_ENERGY_CONSUMPTION_value': 0,
#     'EPS_ENERGY_CONSUMPTION_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_ENERGY_CONSUMPTION_start_bit': 192,
#     'EPS_ENERGY_CONSUMPTION_len': '14'},
#    'EPS_PULL_DRIFT_COMPENSATION_FLAG': {'EPS_PULL_DRIFT_COMPENSATION_FLAG_value': 0,
#     'EPS_PULL_DRIFT_COMPENSATION_FLAG_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_PULL_DRIFT_COMPENSATION_FLAG_start_bit': 206,
#     'EPS_PULL_DRIFT_COMPENSATION_FLAG_len': '1'},
#    'EPS_MCU_TEMP': {'EPS_MCU_TEMP_value': 0,
#     'EPS_MCU_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_MCU_TEMP_start_bit': 216,
#     'EPS_MCU_TEMP_len': '8'},
#    'EPS_MOTOR_RACK_TRQ': {'EPS_MOTOR_RACK_TRQ_value': 0,
#     'EPS_MOTOR_RACK_TRQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_MOTOR_RACK_TRQ_start_bit': 232,
#     'EPS_MOTOR_RACK_TRQ_len': '12'},
#    'EPS_FLASH_FAIL_INFO': {'EPS_FLASH_FAIL_INFO_value': 0,
#     'EPS_FLASH_FAIL_INFO_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_FLASH_FAIL_INFO_start_bit': 263,
#     'EPS_FLASH_FAIL_INFO_len': '1'},
#    'EPS_MOTOR_CURRENT_ID': {'EPS_MOTOR_CURRENT_ID_value': 0,
#     'EPS_MOTOR_CURRENT_ID_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_MOTOR_CURRENT_ID_start_bit': 264,
#     'EPS_MOTOR_CURRENT_ID_len': '9'},
#    'EPS_MOTOR_CURRENT_ID_SEN': {'EPS_MOTOR_CURRENT_ID_SEN_value': 0,
#     'EPS_MOTOR_CURRENT_ID_SEN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_MOTOR_CURRENT_ID_SEN_start_bit': 273,
#     'EPS_MOTOR_CURRENT_ID_SEN_len': '9'},
#    'EPS_MOTOR_CURRENT_IQ': {'EPS_MOTOR_CURRENT_IQ_value': 0,
#     'EPS_MOTOR_CURRENT_IQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_MOTOR_CURRENT_IQ_start_bit': 328,
#     'EPS_MOTOR_CURRENT_IQ_len': '9'},
#    'EPS_MOTOR_CURRENT_IQ_SEN': {'EPS_MOTOR_CURRENT_IQ_SEN_value': 0,
#     'EPS_MOTOR_CURRENT_IQ_SEN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS_MOTOR_CURRENT_IQ_SEN_start_bit': 337,
#     'EPS_MOTOR_CURRENT_IQ_SEN_len': '9'},
#    'EPS1_CRC': {'EPS1_CRC_value': 0,
#     'EPS1_CRC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS1_CRC_start_bit': 464,
#     'EPS1_CRC_len': '16'},
#    'EPS1_MSG_COUNT': {'EPS1_MSG_COUNT_value': 0,
#     'EPS1_MSG_COUNT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EPS1_MSG_COUNT_start_bit': 480,
#     'EPS1_MSG_COUNT_len': '8'}},
#   'total_signals': 30},
#  'ESCL1_FD_100': {'length': '64',
#   'cycle_time': '0.1',
#   'signals': {'ESCL_NOT_LEARNED_WRN': {'ESCL_NOT_LEARNED_WRN_value': 0,
#     'ESCL_NOT_LEARNED_WRN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_NOT_LEARNED_WRN_start_bit': 0,
#     'ESCL_NOT_LEARNED_WRN_len': '1'},
#    'ESCL_NOT_LOCK_WRN': {'ESCL_NOT_LOCK_WRN_value': 0,
#     'ESCL_NOT_LOCK_WRN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_NOT_LOCK_WRN_start_bit': 1,
#     'ESCL_NOT_LOCK_WRN_len': '1'},
#    'ESCL_STATE': {'ESCL_STATE_value': 0,
#     'ESCL_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_STATE_start_bit': 2,
#     'ESCL_STATE_len': '2'},
#    'ESCL_STEER_WHL_JAM_WRN': {'ESCL_STEER_WHL_JAM_WRN_value': 0,
#     'ESCL_STEER_WHL_JAM_WRN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_STEER_WHL_JAM_WRN_start_bit': 4,
#     'ESCL_STEER_WHL_JAM_WRN_len': '1'},
#    'ESCL_WRN_SFTY': {'ESCL_WRN_SFTY_value': 0,
#     'ESCL_WRN_SFTY_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_WRN_SFTY_start_bit': 6,
#     'ESCL_WRN_SFTY_len': '1'}},
#   'total_signals': 5},
#  'ESCL2_SP': {'length': '12',
#   'cycle_time': '0.0',
#   'signals': {'ESCL_AUTH_SUBID': {'ESCL_AUTH_SUBID_value': 0,
#     'ESCL_AUTH_SUBID_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_AUTH_SUBID_start_bit': 0,
#     'ESCL_AUTH_SUBID_len': '8'},
#    'ESCL_AUTH_RSLT': {'ESCL_AUTH_RSLT_value': 0,
#     'ESCL_AUTH_RSLT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_AUTH_RSLT_start_bit': 8,
#     'ESCL_AUTH_RSLT_len': '8'},
#    'ESCL_AUTH_CHALLENGE': {'ESCL_AUTH_CHALLENGE_value': 0,
#     'ESCL_AUTH_CHALLENGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ESCL_AUTH_CHALLENGE_start_bit': 16,
#     'ESCL_AUTH_CHALLENGE_len': '32'}},
#   'total_signals': 3},
#  'FRONTZONE1_SP': {'length': '12',
#   'cycle_time': '0.0',
#   'signals': {'PKE_SUB_ID': {'PKE_SUB_ID_value': 0,
#     'PKE_SUB_ID_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PKE_SUB_ID_start_bit': 0,
#     'PKE_SUB_ID_len': '8'},
#    'PKE_AUTH_RESP': {'PKE_AUTH_RESP_value': 0,
#     'PKE_AUTH_RESP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PKE_AUTH_RESP_start_bit': 8,
#     'PKE_AUTH_RESP_len': '32'}},
#   'total_signals': 2},
#  'FRONTZONE3_MCM_SP': {'length': '64',
#   'cycle_time': '0.0',
#   'signals': {'IMMOVAL5': {'IMMOVAL5_value': 0,
#     'IMMOVAL5_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'IMMOVAL5_start_bit': 0,
#     'IMMOVAL5_len': '64'}},
#   'total_signals': 1},
#  'FRONTZONE4_MCM_SP': {'length': '64',
#   'cycle_time': '0.0',
#   'signals': {'IMMOBILIZATION_STS': {'IMMOBILIZATION_STS_value': 0,
#     'IMMOBILIZATION_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'IMMOBILIZATION_STS_start_bit': 0,
#     'IMMOBILIZATION_STS_len': '64'}},
#   'total_signals': 1},
#  'FRONTZONE5_VCU_SP': {'length': '64',
#   'cycle_time': '0.0',
#   'signals': {'IMMOVAL2': {'IMMOVAL2_value': 0,
#     'IMMOVAL2_Byte_order': 'OPAQUE',
#     'IMMOVAL2_start_bit': 0,
#     'IMMOVAL2_len': '176'}},
#   'total_signals': 1},
#  'FRONTZONE6_VCU_SP': {'length': '64',
#   'cycle_time': '0.0',
#   'signals': {'IMMOVAL4': {'IMMOVAL4_value': 0,
#     'IMMOVAL4_Byte_order': 'OPAQUE',
#     'IMMOVAL4_start_bit': 0,
#     'IMMOVAL4_len': '176'}},
#   'total_signals': 1},
#  'FRONTZONE7_BMS_SP': {'length': '64',
#   'cycle_time': '0.0',
#   'signals': {'IMMOVAL8': {'IMMOVAL8_value': 0,
#     'IMMOVAL8_Byte_order': 'OPAQUE',
#     'IMMOVAL8_start_bit': 0,
#     'IMMOVAL8_len': '176'}},
#   'total_signals': 1},
#  'FRONTZONE8_MCU_SP': {'length': '64',
#   'cycle_time': '0.0',
#   'signals': {'IMMOVAL10': {'IMMOVAL10_value': 0,
#     'IMMOVAL10_Byte_order': 'OPAQUE',
#     'IMMOVAL10_start_bit': 0,
#     'IMMOVAL10_len': '176'}},
#   'total_signals': 1},
#  'FRONTZONE9_SP': {'length': '64',
#   'cycle_time': '0.0',
# ...
#     'VCU_CHARGE_POWER_start_bit': 424,
#     'VCU_CHARGE_POWER_len': '12'},
#    'VCU_REVIVE_MODE_COUNT': {'VCU_REVIVE_MODE_COUNT_value': 0,
#     'VCU_REVIVE_MODE_COUNT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_REVIVE_MODE_COUNT_start_bit': 440,
#     'VCU_REVIVE_MODE_COUNT_len': '8'},
#    'VCU_REVIVE_RANGE': {'VCU_REVIVE_RANGE_value': 0,
#     'VCU_REVIVE_RANGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_REVIVE_RANGE_start_bit': 448,
#     'VCU_REVIVE_RANGE_len': '10'}},
#   'total_signals': 44},
#  'VCU1_FD_20': {'length': '64',
#   'cycle_time': '0.02',
#   'signals': {'EVSE_DC_CURR_OUTPUT_': {'EVSE_DC_CURR_OUTPUT__value': 0,
#     'EVSE_DC_CURR_OUTPUT__Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EVSE_DC_CURR_OUTPUT__start_bit': 0,
#     'EVSE_DC_CURR_OUTPUT__len': '12'},
#    'VCU_CHARGE_DISCHARGE_TRANS': {'VCU_CHARGE_DISCHARGE_TRANS_value': 0,
#     'VCU_CHARGE_DISCHARGE_TRANS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_CHARGE_DISCHARGE_TRANS_start_bit': 12,
#     'VCU_CHARGE_DISCHARGE_TRANS_len': '3'},
#    'EVSE_DC_VOLT_OUTPUT': {'EVSE_DC_VOLT_OUTPUT_value': 0,
#     'EVSE_DC_VOLT_OUTPUT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'EVSE_DC_VOLT_OUTPUT_start_bit': 16,
#     'EVSE_DC_VOLT_OUTPUT_len': '13'},
#    'VCU_AUX_BATTERY_VOLT': {'VCU_AUX_BATTERY_VOLT_value': 0,
#     'VCU_AUX_BATTERY_VOLT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_AUX_BATTERY_VOLT_start_bit': 32,
#     'VCU_AUX_BATTERY_VOLT_len': '8'},
#    'BRAKE_PEDAL_VALUE': {'BRAKE_PEDAL_VALUE_value': 0,
#     'BRAKE_PEDAL_VALUE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BRAKE_PEDAL_VALUE_start_bit': 40,
#     'BRAKE_PEDAL_VALUE_len': '10'},
#    'VEHICLE_CHARGE_MODE_STATE': {'VEHICLE_CHARGE_MODE_STATE_value': 0,
#     'VEHICLE_CHARGE_MODE_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VEHICLE_CHARGE_MODE_STATE_start_bit': 50,
#     'VEHICLE_CHARGE_MODE_STATE_len': '3'},
#    'RAW_ACC_PEDAL_VALUE': {'RAW_ACC_PEDAL_VALUE_value': 0,
#     'RAW_ACC_PEDAL_VALUE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'RAW_ACC_PEDAL_VALUE_start_bit': 56,
#     'RAW_ACC_PEDAL_VALUE_len': '10'},
#    'VEHICLE_STATE': {'VEHICLE_STATE_value': 0,
#     'VEHICLE_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VEHICLE_STATE_start_bit': 66,
#     'VEHICLE_STATE_len': '3'},
#    'INSULATION_MONITORING_STOP_REQ': {'INSULATION_MONITORING_STOP_REQ_value': 0,
#     'INSULATION_MONITORING_STOP_REQ_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'INSULATION_MONITORING_STOP_REQ_start_bit': 71,
#     'INSULATION_MONITORING_STOP_REQ_len': '1'},
#    'VCU_IGN_STS': {'VCU_IGN_STS_value': 0,
#     'VCU_IGN_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_IGN_STS_start_bit': 74,
#     'VCU_IGN_STS_len': '1'},
#    'PRECHARGE_COMPLETE_STATUS': {'PRECHARGE_COMPLETE_STATUS_value': 0,
#     'PRECHARGE_COMPLETE_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PRECHARGE_COMPLETE_STATUS_start_bit': 76,
#     'PRECHARGE_COMPLETE_STATUS_len': '1'},
#    'CONV_CRUISE_ACTIVE_STS': {'CONV_CRUISE_ACTIVE_STS_value': 0,
#     'CONV_CRUISE_ACTIVE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CONV_CRUISE_ACTIVE_STS_start_bit': 79,
#     'CONV_CRUISE_ACTIVE_STS_len': '1'},
#    'VCU_SRS_CRASH_STS': {'VCU_SRS_CRASH_STS_value': 0,
#     'VCU_SRS_CRASH_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_SRS_CRASH_STS_start_bit': 80,
#     'VCU_SRS_CRASH_STS_len': '1'},
#    'VCU_POWERUP_FAILED_STATE': {'VCU_POWERUP_FAILED_STATE_value': 0,
#     'VCU_POWERUP_FAILED_STATE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_POWERUP_FAILED_STATE_start_bit': 81,
#     'VCU_POWERUP_FAILED_STATE_len': '2'},
#    'DRIVE_ENABLE_STATUS': {'DRIVE_ENABLE_STATUS_value': 0,
#     'DRIVE_ENABLE_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'DRIVE_ENABLE_STATUS_start_bit': 84,
#     'DRIVE_ENABLE_STATUS_len': '4'},
#    'VCU_BMS_CONTACTOR_STATUS': {'VCU_BMS_CONTACTOR_STATUS_value': 0,
#     'VCU_BMS_CONTACTOR_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_BMS_CONTACTOR_STATUS_start_bit': 90,
#     'VCU_BMS_CONTACTOR_STATUS_len': '3'},
#    'VCU_BMS_BATTERY_BUS_VOLTAGE': {'VCU_BMS_BATTERY_BUS_VOLTAGE_value': 0,
#     'VCU_BMS_BATTERY_BUS_VOLTAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_BMS_BATTERY_BUS_VOLTAGE_start_bit': 96,
#     'VCU_BMS_BATTERY_BUS_VOLTAGE_len': '13'},
#    'VCU_BMS_TARGET_SOC_TIMETOCHARGE': {'VCU_BMS_TARGET_SOC_TIMETOCHARGE_value': 0,
#     'VCU_BMS_TARGET_SOC_TIMETOCHARGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_BMS_TARGET_SOC_TIMETOCHARGE_start_bit': 160,
#     'VCU_BMS_TARGET_SOC_TIMETOCHARGE_len': '11'},
#    'PADDLE_SHIFT_POSITION': {'PADDLE_SHIFT_POSITION_value': 0,
#     'PADDLE_SHIFT_POSITION_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PADDLE_SHIFT_POSITION_start_bit': 200,
#     'PADDLE_SHIFT_POSITION_len': '3'},
#    'REGEN_ACTIVE_STATUS_REAR': {'REGEN_ACTIVE_STATUS_REAR_value': 0,
#     'REGEN_ACTIVE_STATUS_REAR_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'REGEN_ACTIVE_STATUS_REAR_start_bit': 214,
#     'REGEN_ACTIVE_STATUS_REAR_len': '1'},
#    'REGEN_ACTIVE_STATUS_FRONT': {'REGEN_ACTIVE_STATUS_FRONT_value': 0,
#     'REGEN_ACTIVE_STATUS_FRONT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'REGEN_ACTIVE_STATUS_FRONT_start_bit': 215,
#     'REGEN_ACTIVE_STATUS_FRONT_len': '1'},
#    'ACC_READY': {'ACC_READY_value': 0,
#     'ACC_READY_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ACC_READY_start_bit': 262,
#     'ACC_READY_len': '1'},
#    'STS_CRUISE_OVERRIDE': {'STS_CRUISE_OVERRIDE_value': 0,
#     'STS_CRUISE_OVERRIDE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_CRUISE_OVERRIDE_start_bit': 263,
#     'STS_CRUISE_OVERRIDE_len': '1'},
#    'REGENERATION_DISABLE_STS': {'REGENERATION_DISABLE_STS_value': 0,
#     'REGENERATION_DISABLE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'REGENERATION_DISABLE_STS_start_bit': 436,
#     'REGENERATION_DISABLE_STS_len': '3'},
#    'VCU1FD_CRC': {'VCU1FD_CRC_value': 0,
#     'VCU1FD_CRC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU1FD_CRC_start_bit': 464,
#     'VCU1FD_CRC_len': '16'},
#    'VCU1FD_MSG_CNT': {'VCU1FD_MSG_CNT_value': 0,
#     'VCU1FD_MSG_CNT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU1FD_MSG_CNT_start_bit': 480,
#     'VCU1FD_MSG_CNT_len': '8'}},
#   'total_signals': 26},
#  'VCU2_FD_100': {'length': '64',
#   'cycle_time': '0.1',
#   'signals': {'AMBIENT_TEMP': {'AMBIENT_TEMP_value': 0,
#     'AMBIENT_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'AMBIENT_TEMP_start_bit': 0,
#     'AMBIENT_TEMP_len': '11'},
#    'VCU_OCDC_ACTUAL_U_HV': {'VCU_OCDC_ACTUAL_U_HV_value': 0,
#     'VCU_OCDC_ACTUAL_U_HV_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_OCDC_ACTUAL_U_HV_start_bit': 11,
#     'VCU_OCDC_ACTUAL_U_HV_len': '10'},
#    'ODOMETER_CLUSTER': {'ODOMETER_CLUSTER_value': 0,
#     'ODOMETER_CLUSTER_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ODOMETER_CLUSTER_start_bit': 24,
#     'ODOMETER_CLUSTER_len': '20'},
#    'VCU_HVAC_ENERGY_CONS': {'VCU_HVAC_ENERGY_CONS_value': 0,
#     'VCU_HVAC_ENERGY_CONS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_HVAC_ENERGY_CONS_start_bit': 48,
#     'VCU_HVAC_ENERGY_CONS_len': '10'},
#    'ALERT_MESSAGE': {'ALERT_MESSAGE_value': 0,
#     'ALERT_MESSAGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ALERT_MESSAGE_start_bit': 58,
#     'ALERT_MESSAGE_len': '6'},
#    'VCU_OCDC_OBC_DC_ACTUAL_CUR': {'VCU_OCDC_OBC_DC_ACTUAL_CUR_value': 0,
#     'VCU_OCDC_OBC_DC_ACTUAL_CUR_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_OCDC_OBC_DC_ACTUAL_CUR_start_bit': 64,
#     'VCU_OCDC_OBC_DC_ACTUAL_CUR_len': '11'},
#    'CHARGE_PLUG_STATUS': {'CHARGE_PLUG_STATUS_value': 0,
#     'CHARGE_PLUG_STATUS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CHARGE_PLUG_STATUS_start_bit': 77,
#     'CHARGE_PLUG_STATUS_len': '1'},
#    'CHARGER_LOCK_STS': {'CHARGER_LOCK_STS_value': 0,
#     'CHARGER_LOCK_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'CHARGER_LOCK_STS_start_bit': 80,
#     'CHARGER_LOCK_STS_len': '2'},
#    'HVAC_COOLING_STATUS_BATTERY': {'HVAC_COOLING_STATUS_BATTERY_value': 0,
#     'HVAC_COOLING_STATUS_BATTERY_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'HVAC_COOLING_STATUS_BATTERY_start_bit': 102,
#     'HVAC_COOLING_STATUS_BATTERY_len': '2'},
#    'HVAC_COOLING_STATUS_CABIN': {'HVAC_COOLING_STATUS_CABIN_value': 0,
#     'HVAC_COOLING_STATUS_CABIN_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'HVAC_COOLING_STATUS_CABIN_start_bit': 118,
#     'HVAC_COOLING_STATUS_CABIN_len': '1'},
#    'VCU_BATTERY__COND_ENERGY_CONS': {'VCU_BATTERY__COND_ENERGY_CONS_value': 0,
#     'VCU_BATTERY__COND_ENERGY_CONS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_BATTERY__COND_ENERGY_CONS_start_bit': 120,
#     'VCU_BATTERY__COND_ENERGY_CONS_len': '10'},
#    'BRK_SWITCH': {'BRK_SWITCH_value': 0,
#     'BRK_SWITCH_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'BRK_SWITCH_start_bit': 149,
#     'BRK_SWITCH_len': '2'},
#    'VCU_MOTOR_ENERGY_CONS': {'VCU_MOTOR_ENERGY_CONS_value': 0,
#     'VCU_MOTOR_ENERGY_CONS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_MOTOR_ENERGY_CONS_start_bit': 176,
#     'VCU_MOTOR_ENERGY_CONS_len': '11'},
#    'VCU_EPT_COOLANT_FLOW': {'VCU_EPT_COOLANT_FLOW_value': 0,
#     'VCU_EPT_COOLANT_FLOW_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_EPT_COOLANT_FLOW_start_bit': 224,
#     'VCU_EPT_COOLANT_FLOW_len': '8'},
#    'VCU_EPT_COOLANT_TEMP': {'VCU_EPT_COOLANT_TEMP_value': 0,
#     'VCU_EPT_COOLANT_TEMP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_EPT_COOLANT_TEMP_start_bit': 232,
#     'VCU_EPT_COOLANT_TEMP_len': '8'},
#    'VCU_DRV_ADV_MODE_STS': {'VCU_DRV_ADV_MODE_STS_value': 0,
#     'VCU_DRV_ADV_MODE_STS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_DRV_ADV_MODE_STS_start_bit': 246,
#     'VCU_DRV_ADV_MODE_STS_len': '2'},
#    'VCU_OTHER_CONS': {'VCU_OTHER_CONS_value': 0,
#     'VCU_OTHER_CONS_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_OTHER_CONS_start_bit': 248,
#     'VCU_OTHER_CONS_len': '10'},
#    'VCU_DRV_ADV_MODE': {'VCU_DRV_ADV_MODE_value': 0,
#     'VCU_DRV_ADV_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_DRV_ADV_MODE_start_bit': 260,
#     'VCU_DRV_ADV_MODE_len': '4'},
#    'RANGE_VCU_WCHARGING': {'RANGE_VCU_WCHARGING_value': 0,
#     'RANGE_VCU_WCHARGING_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'RANGE_VCU_WCHARGING_start_bit': 296,
#     'RANGE_VCU_WCHARGING_len': '10'},
#    'VCU_DRV_ADV_ALERT': {'VCU_DRV_ADV_ALERT_value': 0,
#     'VCU_DRV_ADV_ALERT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_DRV_ADV_ALERT_start_bit': 314,
#     'VCU_DRV_ADV_ALERT_len': '3'},
#    'VCU_CUSTOM_MODE': {'VCU_CUSTOM_MODE_value': 0,
#     'VCU_CUSTOM_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_CUSTOM_MODE_start_bit': 317,
#     'VCU_CUSTOM_MODE_len': '1'},
#    'RANGE_VCU': {'RANGE_VCU_value': 0,
#     'RANGE_VCU_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'RANGE_VCU_start_bit': 336,
#     'RANGE_VCU_len': '10'},
#    'LOW_AUX_BATT_TT': {'LOW_AUX_BATT_TT_value': 0,
#     'LOW_AUX_BATT_TT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'LOW_AUX_BATT_TT_start_bit': 346,
#     'LOW_AUX_BATT_TT_len': '2'},
#    'STS_EVWARNING_TT': {'STS_EVWARNING_TT_value': 0,
#     'STS_EVWARNING_TT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_EVWARNING_TT_start_bit': 350,
#     'STS_EVWARNING_TT_len': '2'},
#    'SOC_VCU': {'SOC_VCU_value': 0,
#     'SOC_VCU_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SOC_VCU_start_bit': 352,
#     'SOC_VCU_len': '10'},
#    'MAX_REGEN_CURRENT': {'MAX_REGEN_CURRENT_value': 0,
#     'MAX_REGEN_CURRENT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'MAX_REGEN_CURRENT_start_bit': 384,
#     'MAX_REGEN_CURRENT_len': '12'},
#    'IEB_CUSTOM_DRV_MODE': {'IEB_CUSTOM_DRV_MODE_value': 0,
#     'IEB_CUSTOM_DRV_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'IEB_CUSTOM_DRV_MODE_start_bit': 412,
#     'IEB_CUSTOM_DRV_MODE_len': '4'},
#    'GEAR_ACTUAL': {'GEAR_ACTUAL_value': 0,
#     'GEAR_ACTUAL_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'GEAR_ACTUAL_start_bit': 432,
#     'GEAR_ACTUAL_len': '4'},
#    'PRESS_BRAKE': {'PRESS_BRAKE_value': 0,
#     'PRESS_BRAKE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'PRESS_BRAKE_start_bit': 440,
#     'PRESS_BRAKE_len': '1'},
#    'HIGH_TEMP_LIGHT_OP': {'HIGH_TEMP_LIGHT_OP_value': 0,
#     'HIGH_TEMP_LIGHT_OP_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'HIGH_TEMP_LIGHT_OP_start_bit': 441,
#     'HIGH_TEMP_LIGHT_OP_len': '2'},
#    'STS_CHARGE_LIGHT_TT': {'STS_CHARGE_LIGHT_TT_value': 0,
#     'STS_CHARGE_LIGHT_TT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'STS_CHARGE_LIGHT_TT_start_bit': 443,
#     'STS_CHARGE_LIGHT_TT_len': '2'},
#    'ODO_ERROR_FLAG_VCU': {'ODO_ERROR_FLAG_VCU_value': 0,
#     'ODO_ERROR_FLAG_VCU_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'ODO_ERROR_FLAG_VCU_start_bit': 445,
#     'ODO_ERROR_FLAG_VCU_len': '1'},
#    'VCU_TIME_TO_CHARGE': {'VCU_TIME_TO_CHARGE_value': 0,
#     'VCU_TIME_TO_CHARGE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_TIME_TO_CHARGE_start_bit': 448,
#     'VCU_TIME_TO_CHARGE_len': '11'},
#    'VCU2FD_CRC': {'VCU2FD_CRC_value': 0,
#     'VCU2FD_CRC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU2FD_CRC_start_bit': 464,
#     'VCU2FD_CRC_len': '16'},
#    'VCU2FD_MSG_CNT': {'VCU2FD_MSG_CNT_value': 0,
#     'VCU2FD_MSG_CNT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU2FD_MSG_CNT_start_bit': 480,
#     'VCU2FD_MSG_CNT_len': '8'}},
#   'total_signals': 35},
#  'VCU3_FD_100': {'length': '64',
#   'cycle_time': '0.1',
#   'signals': {'OBC_MAX_CURR_L1': {'OBC_MAX_CURR_L1_value': 0,
#     'OBC_MAX_CURR_L1_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'OBC_MAX_CURR_L1_start_bit': 10,
#     'OBC_MAX_CURR_L1_len': '10'},
#    'OBC_MAX_VOLT_HV': {'OBC_MAX_VOLT_HV_value': 0,
#     'OBC_MAX_VOLT_HV_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'OBC_MAX_VOLT_HV_start_bit': 40,
#     'OBC_MAX_VOLT_HV_len': '13'},
#    'OBC_TARGET_DC_CURR': {'OBC_TARGET_DC_CURR_value': 0,
#     'OBC_TARGET_DC_CURR_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'OBC_TARGET_DC_CURR_start_bit': 54,
#     'OBC_TARGET_DC_CURR_len': '10'},
#    'VCU_DC_SETPOINT_VOLT': {'VCU_DC_SETPOINT_VOLT_value': 0,
#     'VCU_DC_SETPOINT_VOLT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_DC_SETPOINT_VOLT_start_bit': 64,
#     'VCU_DC_SETPOINT_VOLT_len': '13'},
#    'VCU_DCDC_SET_MODE': {'VCU_DCDC_SET_MODE_value': 0,
#     'VCU_DCDC_SET_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_DCDC_SET_MODE_start_bit': 98,
#     'VCU_DCDC_SET_MODE_len': '3'},
#    'OBC_TARGET_MODE': {'OBC_TARGET_MODE_value': 0,
#     'OBC_TARGET_MODE_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'OBC_TARGET_MODE_start_bit': 101,
#     'OBC_TARGET_MODE_len': '3'}},
#   'total_signals': 6},
#  'VCU4_FD_1500': {'length': '64',
#   'cycle_time': '1.5',
#   'signals': {'VIN_NUMBER': {'VIN_NUMBER_value': 0,
#     'VIN_NUMBER_Byte_order': 'OPAQUE',
#     'VIN_NUMBER_start_bit': 0,
#     'VIN_NUMBER_len': '136'}},
#   'total_signals': 1},
#  'VCU_CANNM': {'length': '8',
#   'cycle_time': '0.0',
#   'signals': {'SOURCE_NODE_ID': {'SOURCE_NODE_ID_value': 0,
#     'SOURCE_NODE_ID_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'SOURCE_NODE_ID_start_bit': 0,
#     'SOURCE_NODE_ID_len': '8'},
#    'VCU_WAKEUP_REASON': {'VCU_WAKEUP_REASON_value': 0,
#     'VCU_WAKEUP_REASON_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'VCU_WAKEUP_REASON_start_bit': 16,
#     'VCU_WAKEUP_REASON_len': '8'}},
#   'total_signals': 2},
#  'WLC1_2000': {'length': '64',
#   'cycle_time': '2.0',
#   'signals': {'FOD_ALERT': {'FOD_ALERT_value': 0,
#     'FOD_ALERT_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'FOD_ALERT_start_bit': 0,
#     'FOD_ALERT_len': '1'},
#    'TIME_TO_CHARGE_WLC': {'TIME_TO_CHARGE_WLC_value': 0,
#     'TIME_TO_CHARGE_WLC_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'TIME_TO_CHARGE_WLC_start_bit': 8,
#     'TIME_TO_CHARGE_WLC_len': '8'}},
#   'total_signals': 2},
#  'WLC2_2000': {'length': '64',
#   'cycle_time': '2.0',
#   'signals': {'FOD_ALERT1': {'FOD_ALERT1_value': 0,
#     'FOD_ALERT1_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'FOD_ALERT1_start_bit': 0,
#     'FOD_ALERT1_len': '1'},
#    'TIME_TO_CHARGE1': {'TIME_TO_CHARGE1_value': 0,
#     'TIME_TO_CHARGE1_Byte_order': 'MOST-SIGNIFICANT-BYTE-LAST',
#     'TIME_TO_CHARGE1_start_bit': 8,
#     'TIME_TO_CHARGE1_len': '8'}},
#   'total_signals': 2}}

# %%
def generate_pdu_metadata(service_data, pdu_data):
    messages = {}
    for pdu_name, pdu_info in pdu_data.items():
        key = normalize_name(pdu_name)
        matched_service = service_data.get(key, {'service_interface': 'N/A', 'service_id': '', 'event_ids': ''})
        messages[pdu_name] = {
            'pdu_name': pdu_name,
            'service_interface': matched_service['service_interface'],
            'service_id': matched_service['service_id'],
            'event_ids': matched_service['event_ids'],
            'length': pdu_info['length'],
            'cycle_time': pdu_info['cycle_time'],
            'total_signals': pdu_info['total_signals'],
            'signals': pdu_info['signals']
        }
    return {"Messages": messages}

# %%
# Execute
service_data = parse_service_interfaces(SERVICE_FILE)
pdu_data = parse_rbs_pdus(RBS_FILE)
final_metadata = generate_pdu_metadata(service_data, pdu_data)

with open(OUTPUT_JSON, 'w') as f:
    json.dump(final_metadata, f, indent=2)

print(f"✅ PDU metadata with signals saved to: {OUTPUT_JSON}")
# Out:
# ✅ PDU metadata with signals saved to: pdu_signal_metadata.json
